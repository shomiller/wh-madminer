# %% [markdown]
# # 2. Signal Generation

# %% [markdown]
# Here we set up the signal generation processes for both $W^+H$ and $W^-H$ separately, so that they can later be analyzed.

# %%
madminer_src_path = '/home/shomiller/madminer'
import sys
import os
sys.path.append(madminer_src_path)

from __future__ import absolute_import, division, print_function, unicode_literals
import logging
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

from madminer.core import MadMiner
from madminer.lhe import LHEReader
from madminer.sampling import SampleAugmenter, combine_and_shuffle
from madminer.plotting import plot_distributions

from scipy.optimize import curve_fit

import madminer.__version__
print( 'MadMiner version: {}'.format(madminer.__version__) )
# Out:
# MadMiner version: 0.3.0

# %%
# MadMiner output
logging.basicConfig(
    format='%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s',
    datefmt='%H:%M',
    level=logging.INFO
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %%
mg_dir = '/home/shomiller/MG5_aMC_v2_6_2'

# %% [markdown]
# We load the MadMiner morphing setup created in the previous section, which includes morphing benchmarks to span the full parameter space of $(C_{H\square}, C_{HD}, C_{HW}, C_{Hq}^{(3)})$.

# %%
miner = MadMiner()
miner.load('data/wh_smeft_setup.h5')
# Out:
# 14:42 madminer.core        INFO    Found 4 parameters:
# 14:42 madminer.core        INFO       cHbox (LHA: frblock 24, maximal power in squared ME: (2,), range: (-10.0, 10.0))
# 14:42 madminer.core        INFO       cHDD (LHA: frblock 25, maximal power in squared ME: (2,), range: (-10.0, 10.0))
# 14:42 madminer.core        INFO       cHW (LHA: frblock 28, maximal power in squared ME: (2,), range: (-10.0, 10.0))
# 14:42 madminer.core        INFO       cHq3 (LHA: frblock 49, maximal power in squared ME: (2,), range: (-10.0, 10.0))
# 14:42 madminer.core        INFO    Found 15 benchmarks:
# 14:42 madminer.core        INFO       sm: cHbox = 0.00e+00, cHDD = 0.00e+00, cHW = 0.00e+00, cHq3 = 0.00e+00
# 14:42 madminer.core        INFO       morphing_basis_vector_1: cHbox = 5.41, cHDD = 5.11, cHW = -5.33e+00, cHq3 = -2.67e+00
# 14:42 madminer.core        INFO       morphing_basis_vector_2: cHbox = 7.24, cHDD = -2.47e+00, cHW = -7.09e+00, cHq3 = 3.53
# 14:42 madminer.core        INFO       morphing_basis_vector_3: cHbox = 6.44, cHDD = -5.44e+00, cHW = -2.28e-02, cHq3 = -6.99e+00
# 14:42 madminer.core        INFO       morphing_basis_vector_4: cHbox = -9.59e+00, cHDD = -8.93e+00, cHW = 9.79, cHq3 = 8.23
# 14:42 madminer.core        INFO       morphing_basis_vector_5: cHbox = -4.70e+00, cHDD = 8.02, cHW = -8.43e+00, cHq3 = 5.12
# 14:42 madminer.core        INFO       morphing_basis_vector_6: cHbox = -7.06e+00, cHDD = -6.25e+00, cHW = -7.53e+00, cHq3 = 2.61
# 14:42 madminer.core        INFO       morphing_basis_vector_7: cHbox = 9.79, cHDD = -7.53e+00, cHW = -9.08e+00, cHq3 = -8.35e+00
# 14:42 madminer.core        INFO       morphing_basis_vector_8: cHbox = -6.93e+00, cHDD = 1.78, cHW = -2.29e+00, cHq3 = -8.57e+00
# 14:42 madminer.core        INFO       morphing_basis_vector_9: cHbox = 4.95, cHDD = 8.99, cHW = -4.87e+00, cHq3 = -6.95e+00
# 14:42 madminer.core        INFO       morphing_basis_vector_10: cHbox = 9.23, cHDD = 0.69, cHW = -3.78e+00, cHq3 = -9.38e+00
# 14:42 madminer.core        INFO       morphing_basis_vector_11: cHbox = 1.76, cHDD = -2.05e+00, cHW = -8.52e+00, cHq3 = 5.33
# 14:42 madminer.core        INFO       morphing_basis_vector_12: cHbox = -9.20e+00, cHDD = 1.24, cHW = 9.38, cHq3 = 3.28
# 14:42 madminer.core        INFO       morphing_basis_vector_13: cHbox = 7.02, cHDD = 3.01, cHW = 2.08, cHq3 = 9.73
# 14:42 madminer.core        INFO       morphing_basis_vector_14: cHbox = 9.00, cHDD = -2.94e+00, cHW = 9.51, cHq3 = 4.49
# 14:42 madminer.core        INFO    Found morphing setup with 15 components
# 14:42 madminer.core        INFO    Found systematics setup with 3 nuisance parameter groups

# %% [markdown]
# We'll generate a number of samples simulataneously using MadMiner.run_multiple().
#
# A quick summary of what's in the cards used for the generation:

# %% [markdown]
# `cards/signal_processes/proc_card_wph_mu_smeftsim.dat`:
#
#     import model SMEFTsim
#     generate p p > w+ h > mu+ vm b b~ QCD=0 QED=99 NP=1
#
#
# `cards/run_card_wh_parton.dat`:
#
#     50000 = nevents
#     6500.0   = ebeam1
#     6500.0   = ebeam2`
#     35.0 = ptb
#     10.0 = ptl
#     25.0 = misset
#     30.0 = ptjmax
#     2.5 = etab
#     2.5 = etal
#     80.0 = mmbb
#     160.0 = mmbbmax
#     0.4 = drbb
#     0.4 = drbl
#     True = cut_decays

# %% [markdown]
# We generate the events in a number of small batches, using the SM benchmark for sampling.

# %%
nrun = 40

# %% [markdown]
# ## 1. $W^+(\mu^+ \nu_{\mu})H(b\bar{b})$

# %%
miner.run_multiple(
    mg_directory=mg_dir,
    log_directory='logs/wph_mu_smeftsim',
    mg_process_directory='./signal_samples/wph_mu_smeftsim',
    proc_card_file='../cards/signal_processes/proc_card_wph_mu_smeftsim.dat',
    param_card_template_file='../cards/param_card_template_smeftsim.dat',
    run_card_files=['../cards/run_card_wh_parton.dat' for i in range(nrun)],
    sample_benchmarks=['sm'],
    initial_command=None
)
# Out:
# 14:42 madminer.utils.inter INFO    Generating MadGraph process folder from ../cards/signal_processes/proc_card_wph_mu_smeftsim.dat at ./wph_mu_smeftsim
# 14:42 madminer.core        INFO    Run 0
# 14:42 madminer.core        INFO      Sampling from benchmark: sm
# 14:42 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 14:42 madminer.core        INFO      Original Pythia8 card:   None
# 14:42 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_0.dat
# 14:42 madminer.core        INFO      Copied Pythia8 card:     None
# 14:42 madminer.core        INFO      Param card:              /madminer/cards/param_card_0.dat
# 14:42 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_0.dat
# 14:42 madminer.core        INFO      Log file:                run_0.log
# 14:42 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_0.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_0.dat
# 14:42 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 14:56 madminer.core        INFO    Run 1
# 14:56 madminer.core        INFO      Sampling from benchmark: sm
# 14:56 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 14:56 madminer.core        INFO      Original Pythia8 card:   None
# 14:56 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_1.dat
# 14:56 madminer.core        INFO      Copied Pythia8 card:     None
# 14:56 madminer.core        INFO      Param card:              /madminer/cards/param_card_1.dat
# 14:56 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_1.dat
# 14:56 madminer.core        INFO      Log file:                run_1.log
# 14:56 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_1.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_1.dat
# 14:56 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 15:12 madminer.core        INFO    Run 2
# 15:12 madminer.core        INFO      Sampling from benchmark: sm
# 15:12 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 15:12 madminer.core        INFO      Original Pythia8 card:   None
# 15:12 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_2.dat
# 15:12 madminer.core        INFO      Copied Pythia8 card:     None
# 15:12 madminer.core        INFO      Param card:              /madminer/cards/param_card_2.dat
# 15:12 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_2.dat
# 15:12 madminer.core        INFO      Log file:                run_2.log
# 15:12 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_2.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_2.dat
# 15:12 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 15:25 madminer.core        INFO    Run 3
# 15:25 madminer.core        INFO      Sampling from benchmark: sm
# 15:25 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 15:25 madminer.core        INFO      Original Pythia8 card:   None
# 15:25 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_3.dat
# 15:25 madminer.core        INFO      Copied Pythia8 card:     None
# 15:25 madminer.core        INFO      Param card:              /madminer/cards/param_card_3.dat
# 15:25 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_3.dat
# 15:25 madminer.core        INFO      Log file:                run_3.log
# 15:25 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_3.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_3.dat
# 15:25 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 15:39 madminer.core        INFO    Run 4
# 15:39 madminer.core        INFO      Sampling from benchmark: sm
# 15:39 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 15:39 madminer.core        INFO      Original Pythia8 card:   None
# 15:39 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_4.dat
# 15:39 madminer.core        INFO      Copied Pythia8 card:     None
# 15:39 madminer.core        INFO      Param card:              /madminer/cards/param_card_4.dat
# 15:39 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_4.dat
# 15:39 madminer.core        INFO      Log file:                run_4.log
# 15:39 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_4.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_4.dat
# 15:39 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 15:53 madminer.core        INFO    Run 5
# 15:53 madminer.core        INFO      Sampling from benchmark: sm
# 15:53 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 15:53 madminer.core        INFO      Original Pythia8 card:   None
# 15:53 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_5.dat
# 15:53 madminer.core        INFO      Copied Pythia8 card:     None
# 15:53 madminer.core        INFO      Param card:              /madminer/cards/param_card_5.dat
# 15:53 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_5.dat
# 15:53 madminer.core        INFO      Log file:                run_5.log
# 15:53 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_5.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_5.dat
# 15:53 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 16:06 madminer.core        INFO    Run 6
# 16:06 madminer.core        INFO      Sampling from benchmark: sm
# 16:06 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 16:06 madminer.core        INFO      Original Pythia8 card:   None
# 16:06 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_6.dat
# 16:06 madminer.core        INFO      Copied Pythia8 card:     None
# 16:06 madminer.core        INFO      Param card:              /madminer/cards/param_card_6.dat
# 16:06 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_6.dat
# 16:06 madminer.core        INFO      Log file:                run_6.log
# 16:06 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_6.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_6.dat
# 16:06 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 16:22 madminer.core        INFO    Run 7
# 16:22 madminer.core        INFO      Sampling from benchmark: sm
# 16:22 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 16:22 madminer.core        INFO      Original Pythia8 card:   None
# 16:22 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_7.dat
# 16:22 madminer.core        INFO      Copied Pythia8 card:     None
# 16:22 madminer.core        INFO      Param card:              /madminer/cards/param_card_7.dat
# 16:22 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_7.dat
# 16:22 madminer.core        INFO      Log file:                run_7.log
# 16:22 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_7.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_7.dat
# 16:22 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 16:35 madminer.core        INFO    Run 8
# 16:35 madminer.core        INFO      Sampling from benchmark: sm
# 16:35 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 16:35 madminer.core        INFO      Original Pythia8 card:   None
# 16:35 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_8.dat
# 16:35 madminer.core        INFO      Copied Pythia8 card:     None
# 16:35 madminer.core        INFO      Param card:              /madminer/cards/param_card_8.dat
# 16:35 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_8.dat
# 16:35 madminer.core        INFO      Log file:                run_8.log
# 16:35 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_8.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_8.dat
# 16:35 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 16:48 madminer.core        INFO    Run 9
# 16:48 madminer.core        INFO      Sampling from benchmark: sm
# 16:48 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 16:48 madminer.core        INFO      Original Pythia8 card:   None
# 16:48 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_9.dat
# 16:48 madminer.core        INFO      Copied Pythia8 card:     None
# 16:48 madminer.core        INFO      Param card:              /madminer/cards/param_card_9.dat
# 16:48 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_9.dat
# 16:48 madminer.core        INFO      Log file:                run_9.log
# 16:48 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_9.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_9.dat
# 16:48 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 17:01 madminer.core        INFO    Run 10
# 17:01 madminer.core        INFO      Sampling from benchmark: sm
# 17:01 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 17:01 madminer.core        INFO      Original Pythia8 card:   None
# 17:01 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_10.dat
# 17:01 madminer.core        INFO      Copied Pythia8 card:     None
# 17:01 madminer.core        INFO      Param card:              /madminer/cards/param_card_10.dat
# 17:01 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_10.dat
# 17:01 madminer.core        INFO      Log file:                run_10.log
# 17:01 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_10.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_10.dat
# 17:01 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 17:14 madminer.core        INFO    Run 11
# 17:14 madminer.core        INFO      Sampling from benchmark: sm
# 17:14 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 17:14 madminer.core        INFO      Original Pythia8 card:   None
# 17:14 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_11.dat
# 17:14 madminer.core        INFO      Copied Pythia8 card:     None
# 17:14 madminer.core        INFO      Param card:              /madminer/cards/param_card_11.dat
# 17:14 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_11.dat
# 17:14 madminer.core        INFO      Log file:                run_11.log
# 17:14 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_11.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_11.dat
# 17:14 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 17:27 madminer.core        INFO    Run 12
# 17:27 madminer.core        INFO      Sampling from benchmark: sm
# 17:27 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 17:27 madminer.core        INFO      Original Pythia8 card:   None
# 17:27 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_12.dat
# 17:27 madminer.core        INFO      Copied Pythia8 card:     None
# 17:27 madminer.core        INFO      Param card:              /madminer/cards/param_card_12.dat
# 17:27 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_12.dat
# 17:27 madminer.core        INFO      Log file:                run_12.log
# 17:27 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_12.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_12.dat
# 17:27 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 17:40 madminer.core        INFO    Run 13
# 17:40 madminer.core        INFO      Sampling from benchmark: sm
# 17:40 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 17:40 madminer.core        INFO      Original Pythia8 card:   None
# 17:40 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_13.dat
# 17:40 madminer.core        INFO      Copied Pythia8 card:     None
# 17:40 madminer.core        INFO      Param card:              /madminer/cards/param_card_13.dat
# 17:40 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_13.dat
# 17:40 madminer.core        INFO      Log file:                run_13.log
# 17:40 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_13.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_13.dat
# 17:40 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 17:54 madminer.core        INFO    Run 14
# 17:54 madminer.core        INFO      Sampling from benchmark: sm
# 17:54 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 17:54 madminer.core        INFO      Original Pythia8 card:   None
# 17:54 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_14.dat
# 17:54 madminer.core        INFO      Copied Pythia8 card:     None
# 17:54 madminer.core        INFO      Param card:              /madminer/cards/param_card_14.dat
# 17:54 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_14.dat
# 17:54 madminer.core        INFO      Log file:                run_14.log
# 17:54 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_14.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_14.dat
# 17:54 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 18:07 madminer.core        INFO    Run 15
# 18:07 madminer.core        INFO      Sampling from benchmark: sm
# 18:07 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 18:07 madminer.core        INFO      Original Pythia8 card:   None
# 18:07 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_15.dat
# 18:07 madminer.core        INFO      Copied Pythia8 card:     None
# 18:07 madminer.core        INFO      Param card:              /madminer/cards/param_card_15.dat
# 18:07 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_15.dat
# 18:07 madminer.core        INFO      Log file:                run_15.log
# 18:07 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_15.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_15.dat
# 18:07 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 18:20 madminer.core        INFO    Run 16
# 18:20 madminer.core        INFO      Sampling from benchmark: sm
# 18:20 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 18:20 madminer.core        INFO      Original Pythia8 card:   None
# 18:20 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_16.dat
# 18:20 madminer.core        INFO      Copied Pythia8 card:     None
# 18:20 madminer.core        INFO      Param card:              /madminer/cards/param_card_16.dat
# 18:20 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_16.dat
# 18:20 madminer.core        INFO      Log file:                run_16.log
# 18:20 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_16.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_16.dat
# 18:20 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 18:37 madminer.core        INFO    Run 17
# 18:37 madminer.core        INFO      Sampling from benchmark: sm
# 18:37 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 18:37 madminer.core        INFO      Original Pythia8 card:   None
# 18:37 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_17.dat
# 18:37 madminer.core        INFO      Copied Pythia8 card:     None
# 18:37 madminer.core        INFO      Param card:              /madminer/cards/param_card_17.dat
# 18:37 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_17.dat
# 18:37 madminer.core        INFO      Log file:                run_17.log
# 18:37 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_17.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_17.dat
# 18:37 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 18:50 madminer.core        INFO    Run 18
# 18:50 madminer.core        INFO      Sampling from benchmark: sm
# 18:50 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 18:50 madminer.core        INFO      Original Pythia8 card:   None
# 18:50 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_18.dat
# 18:50 madminer.core        INFO      Copied Pythia8 card:     None
# 18:50 madminer.core        INFO      Param card:              /madminer/cards/param_card_18.dat
# 18:50 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_18.dat
# 18:50 madminer.core        INFO      Log file:                run_18.log
# 18:50 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_18.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_18.dat
# 18:50 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 19:04 madminer.core        INFO    Run 19
# 19:04 madminer.core        INFO      Sampling from benchmark: sm
# 19:04 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 19:04 madminer.core        INFO      Original Pythia8 card:   None
# 19:04 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_19.dat
# 19:04 madminer.core        INFO      Copied Pythia8 card:     None
# 19:04 madminer.core        INFO      Param card:              /madminer/cards/param_card_19.dat
# 19:04 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_19.dat
# 19:04 madminer.core        INFO      Log file:                run_19.log
# 19:04 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_19.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_19.dat
# 19:04 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 19:17 madminer.core        INFO    Run 20
# 19:17 madminer.core        INFO      Sampling from benchmark: sm
# 19:17 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 19:17 madminer.core        INFO      Original Pythia8 card:   None
# 19:17 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_20.dat
# 19:17 madminer.core        INFO      Copied Pythia8 card:     None
# 19:17 madminer.core        INFO      Param card:              /madminer/cards/param_card_20.dat
# 19:17 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_20.dat
# 19:17 madminer.core        INFO      Log file:                run_20.log
# 19:17 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_20.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_20.dat
# 19:17 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 19:29 madminer.core        INFO    Run 21
# 19:29 madminer.core        INFO      Sampling from benchmark: sm
# 19:29 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 19:29 madminer.core        INFO      Original Pythia8 card:   None
# 19:29 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_21.dat
# 19:29 madminer.core        INFO      Copied Pythia8 card:     None
# 19:29 madminer.core        INFO      Param card:              /madminer/cards/param_card_21.dat
# 19:29 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_21.dat
# 19:29 madminer.core        INFO      Log file:                run_21.log
# 19:29 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_21.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_21.dat
# 19:29 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 19:43 madminer.core        INFO    Run 22
# 19:43 madminer.core        INFO      Sampling from benchmark: sm
# 19:43 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 19:43 madminer.core        INFO      Original Pythia8 card:   None
# 19:43 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_22.dat
# 19:43 madminer.core        INFO      Copied Pythia8 card:     None
# 19:43 madminer.core        INFO      Param card:              /madminer/cards/param_card_22.dat
# 19:43 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_22.dat
# 19:43 madminer.core        INFO      Log file:                run_22.log
# 19:43 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_22.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_22.dat
# 19:43 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 19:58 madminer.core        INFO    Run 23
# 19:58 madminer.core        INFO      Sampling from benchmark: sm
# 19:58 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 19:58 madminer.core        INFO      Original Pythia8 card:   None
# 19:58 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_23.dat
# 19:58 madminer.core        INFO      Copied Pythia8 card:     None
# 19:58 madminer.core        INFO      Param card:              /madminer/cards/param_card_23.dat
# 19:58 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_23.dat
# 19:58 madminer.core        INFO      Log file:                run_23.log
# 19:58 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_23.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_23.dat
# 19:58 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 20:11 madminer.core        INFO    Run 24
# 20:11 madminer.core        INFO      Sampling from benchmark: sm
# 20:11 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 20:11 madminer.core        INFO      Original Pythia8 card:   None
# 20:11 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_24.dat
# 20:11 madminer.core        INFO      Copied Pythia8 card:     None
# 20:11 madminer.core        INFO      Param card:              /madminer/cards/param_card_24.dat
# 20:11 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_24.dat
# 20:11 madminer.core        INFO      Log file:                run_24.log
# 20:11 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_24.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_24.dat
# 20:11 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 20:24 madminer.core        INFO    Run 25
# 20:24 madminer.core        INFO      Sampling from benchmark: sm
# 20:24 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 20:24 madminer.core        INFO      Original Pythia8 card:   None
# 20:24 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_25.dat
# 20:24 madminer.core        INFO      Copied Pythia8 card:     None
# 20:24 madminer.core        INFO      Param card:              /madminer/cards/param_card_25.dat
# 20:24 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_25.dat
# 20:24 madminer.core        INFO      Log file:                run_25.log
# 20:24 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_25.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_25.dat
# 20:24 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 20:38 madminer.core        INFO    Run 26
# 20:38 madminer.core        INFO      Sampling from benchmark: sm
# 20:38 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 20:38 madminer.core        INFO      Original Pythia8 card:   None
# 20:38 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_26.dat
# 20:38 madminer.core        INFO      Copied Pythia8 card:     None
# 20:38 madminer.core        INFO      Param card:              /madminer/cards/param_card_26.dat
# 20:38 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_26.dat
# 20:38 madminer.core        INFO      Log file:                run_26.log
# 20:38 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_26.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_26.dat
# 20:38 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 20:51 madminer.core        INFO    Run 27
# 20:51 madminer.core        INFO      Sampling from benchmark: sm
# 20:51 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 20:51 madminer.core        INFO      Original Pythia8 card:   None
# 20:51 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_27.dat
# 20:51 madminer.core        INFO      Copied Pythia8 card:     None
# 20:51 madminer.core        INFO      Param card:              /madminer/cards/param_card_27.dat
# 20:51 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_27.dat
# 20:51 madminer.core        INFO      Log file:                run_27.log
# 20:51 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_27.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_27.dat
# 20:51 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 21:04 madminer.core        INFO    Run 28
# 21:04 madminer.core        INFO      Sampling from benchmark: sm
# 21:04 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 21:04 madminer.core        INFO      Original Pythia8 card:   None
# 21:04 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_28.dat
# 21:04 madminer.core        INFO      Copied Pythia8 card:     None
# 21:04 madminer.core        INFO      Param card:              /madminer/cards/param_card_28.dat
# 21:04 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_28.dat
# 21:04 madminer.core        INFO      Log file:                run_28.log
# 21:04 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_28.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_28.dat
# 21:04 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 21:20 madminer.core        INFO    Run 29
# 21:20 madminer.core        INFO      Sampling from benchmark: sm
# 21:20 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 21:20 madminer.core        INFO      Original Pythia8 card:   None
# 21:20 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_29.dat
# 21:20 madminer.core        INFO      Copied Pythia8 card:     None
# 21:20 madminer.core        INFO      Param card:              /madminer/cards/param_card_29.dat
# 21:20 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_29.dat
# 21:20 madminer.core        INFO      Log file:                run_29.log
# 21:20 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_29.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_29.dat
# 21:20 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 21:35 madminer.core        INFO    Run 30
# 21:35 madminer.core        INFO      Sampling from benchmark: sm
# 21:35 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 21:35 madminer.core        INFO      Original Pythia8 card:   None
# 21:35 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_30.dat
# 21:35 madminer.core        INFO      Copied Pythia8 card:     None
# 21:35 madminer.core        INFO      Param card:              /madminer/cards/param_card_30.dat
# 21:35 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_30.dat
# 21:35 madminer.core        INFO      Log file:                run_30.log
# 21:35 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_30.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_30.dat
# 21:35 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 21:49 madminer.core        INFO    Run 31
# 21:49 madminer.core        INFO      Sampling from benchmark: sm
# 21:49 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 21:49 madminer.core        INFO      Original Pythia8 card:   None
# 21:49 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_31.dat
# 21:49 madminer.core        INFO      Copied Pythia8 card:     None
# 21:49 madminer.core        INFO      Param card:              /madminer/cards/param_card_31.dat
# 21:49 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_31.dat
# 21:49 madminer.core        INFO      Log file:                run_31.log
# 21:49 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_31.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_31.dat
# 21:49 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 22:04 madminer.core        INFO    Run 32
# 22:04 madminer.core        INFO      Sampling from benchmark: sm
# 22:04 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 22:04 madminer.core        INFO      Original Pythia8 card:   None
# 22:04 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_32.dat
# 22:04 madminer.core        INFO      Copied Pythia8 card:     None
# 22:04 madminer.core        INFO      Param card:              /madminer/cards/param_card_32.dat
# 22:04 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_32.dat
# 22:04 madminer.core        INFO      Log file:                run_32.log
# 22:04 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_32.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_32.dat
# 22:04 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 22:18 madminer.core        INFO    Run 33
# 22:18 madminer.core        INFO      Sampling from benchmark: sm
# 22:18 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 22:18 madminer.core        INFO      Original Pythia8 card:   None
# 22:18 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_33.dat
# 22:18 madminer.core        INFO      Copied Pythia8 card:     None
# 22:18 madminer.core        INFO      Param card:              /madminer/cards/param_card_33.dat
# 22:18 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_33.dat
# 22:18 madminer.core        INFO      Log file:                run_33.log
# 22:18 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_33.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_33.dat
# 22:18 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 22:32 madminer.core        INFO    Run 34
# 22:32 madminer.core        INFO      Sampling from benchmark: sm
# 22:32 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 22:32 madminer.core        INFO      Original Pythia8 card:   None
# 22:32 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_34.dat
# 22:32 madminer.core        INFO      Copied Pythia8 card:     None
# 22:32 madminer.core        INFO      Param card:              /madminer/cards/param_card_34.dat
# 22:32 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_34.dat
# 22:32 madminer.core        INFO      Log file:                run_34.log
# 22:32 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_34.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_34.dat
# 22:32 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 22:45 madminer.core        INFO    Run 35
# 22:45 madminer.core        INFO      Sampling from benchmark: sm
# 22:45 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 22:45 madminer.core        INFO      Original Pythia8 card:   None
# 22:45 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_35.dat
# 22:45 madminer.core        INFO      Copied Pythia8 card:     None
# 22:45 madminer.core        INFO      Param card:              /madminer/cards/param_card_35.dat
# 22:45 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_35.dat
# 22:45 madminer.core        INFO      Log file:                run_35.log
# 22:45 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_35.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_35.dat
# 22:45 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 22:58 madminer.core        INFO    Run 36
# 22:58 madminer.core        INFO      Sampling from benchmark: sm
# 22:58 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 22:58 madminer.core        INFO      Original Pythia8 card:   None
# 22:58 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_36.dat
# 22:58 madminer.core        INFO      Copied Pythia8 card:     None
# 22:58 madminer.core        INFO      Param card:              /madminer/cards/param_card_36.dat
# 22:58 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_36.dat
# 22:58 madminer.core        INFO      Log file:                run_36.log
# 22:58 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_36.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_36.dat
# 22:58 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 23:12 madminer.core        INFO    Run 37
# 23:12 madminer.core        INFO      Sampling from benchmark: sm
# 23:12 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 23:12 madminer.core        INFO      Original Pythia8 card:   None
# 23:12 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_37.dat
# 23:12 madminer.core        INFO      Copied Pythia8 card:     None
# 23:12 madminer.core        INFO      Param card:              /madminer/cards/param_card_37.dat
# 23:12 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_37.dat
# 23:12 madminer.core        INFO      Log file:                run_37.log
# 23:12 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_37.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_37.dat
# 23:12 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 23:27 madminer.core        INFO    Run 38
# 23:27 madminer.core        INFO      Sampling from benchmark: sm
# 23:27 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 23:27 madminer.core        INFO      Original Pythia8 card:   None
# 23:27 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_38.dat
# 23:27 madminer.core        INFO      Copied Pythia8 card:     None
# 23:27 madminer.core        INFO      Param card:              /madminer/cards/param_card_38.dat
# 23:27 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_38.dat
# 23:27 madminer.core        INFO      Log file:                run_38.log
# 23:27 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_38.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_38.dat
# 23:27 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 23:40 madminer.core        INFO    Run 39
# 23:40 madminer.core        INFO      Sampling from benchmark: sm
# 23:40 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 23:40 madminer.core        INFO      Original Pythia8 card:   None
# 23:40 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_39.dat
# 23:40 madminer.core        INFO      Copied Pythia8 card:     None
# 23:40 madminer.core        INFO      Param card:              /madminer/cards/param_card_39.dat
# 23:40 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_39.dat
# 23:40 madminer.core        INFO      Log file:                run_39.log
# 23:40 madminer.core        INFO    Creating param and reweight cards in ./wph_mu_smeftsim//madminer/cards/param_card_39.dat, ./wph_mu_smeftsim//madminer/cards/reweight_card_39.dat
# 23:40 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_mu_smeftsim
# 23:53 madminer.core        INFO    Finished running MadGraph! Please check that events were succesfully generated in the following folders:
#
# ./wph_mu_smeftsim/Events/run_01
# ./wph_mu_smeftsim/Events/run_02
# ./wph_mu_smeftsim/Events/run_03
# ./wph_mu_smeftsim/Events/run_04
# ./wph_mu_smeftsim/Events/run_05
# ./wph_mu_smeftsim/Events/run_06
# ./wph_mu_smeftsim/Events/run_07
# ./wph_mu_smeftsim/Events/run_08
# ./wph_mu_smeftsim/Events/run_09
# ./wph_mu_smeftsim/Events/run_10
# ./wph_mu_smeftsim/Events/run_11
# ./wph_mu_smeftsim/Events/run_12
# ./wph_mu_smeftsim/Events/run_13
# ./wph_mu_smeftsim/Events/run_14
# ./wph_mu_smeftsim/Events/run_15
# ./wph_mu_smeftsim/Events/run_16
# ./wph_mu_smeftsim/Events/run_17
# ./wph_mu_smeftsim/Events/run_18
# ./wph_mu_smeftsim/Events/run_19
# ./wph_mu_smeftsim/Events/run_20
# ./wph_mu_smeftsim/Events/run_21
# ./wph_mu_smeftsim/Events/run_22
# ./wph_mu_smeftsim/Events/run_23
# ./wph_mu_smeftsim/Events/run_24
# ./wph_mu_smeftsim/Events/run_25
# ./wph_mu_smeftsim/Events/run_26
# ./wph_mu_smeftsim/Events/run_27
# ./wph_mu_smeftsim/Events/run_28
# ./wph_mu_smeftsim/Events/run_29
# ./wph_mu_smeftsim/Events/run_30
# ./wph_mu_smeftsim/Events/run_31
# ./wph_mu_smeftsim/Events/run_32
# ./wph_mu_smeftsim/Events/run_33
# ./wph_mu_smeftsim/Events/run_34
# ./wph_mu_smeftsim/Events/run_35
# ./wph_mu_smeftsim/Events/run_36
# ./wph_mu_smeftsim/Events/run_37
# ./wph_mu_smeftsim/Events/run_38
# ./wph_mu_smeftsim/Events/run_39
# ./wph_mu_smeftsim/Events/run_40

# %% [markdown]
# ## 2. $W^+(e^+\nu_{e})H(b\bar{b})$

# %%
miner.run_multiple(
    mg_directory=mg_dir,
    log_directory='logs/wph_e_smeftsim',
    mg_process_directory='./signal_samples/wph_e_smeftsim',
    proc_card_file='../cards/signal_processes/proc_card_wph_e_smeftsim.dat',
    param_card_template_file='../cards/param_card_template_smeftsim.dat',
    run_card_files=['../cards/run_card_wh_parton.dat' for i in range(nrun)],
    sample_benchmarks=['sm'],
    initial_command=None
)
# Out:
# 23:53 madminer.utils.inter INFO    Generating MadGraph process folder from ../cards/signal_processes/proc_card_wph_e_smeftsim.dat at ./wph_e_smeftsim
# 23:53 madminer.core        INFO    Run 0
# 23:53 madminer.core        INFO      Sampling from benchmark: sm
# 23:53 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 23:53 madminer.core        INFO      Original Pythia8 card:   None
# 23:53 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_0.dat
# 23:53 madminer.core        INFO      Copied Pythia8 card:     None
# 23:53 madminer.core        INFO      Param card:              /madminer/cards/param_card_0.dat
# 23:53 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_0.dat
# 23:53 madminer.core        INFO      Log file:                run_0.log
# 23:53 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_0.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_0.dat
# 23:53 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 00:06 madminer.core        INFO    Run 1
# 00:06 madminer.core        INFO      Sampling from benchmark: sm
# 00:06 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 00:06 madminer.core        INFO      Original Pythia8 card:   None
# 00:06 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_1.dat
# 00:06 madminer.core        INFO      Copied Pythia8 card:     None
# 00:06 madminer.core        INFO      Param card:              /madminer/cards/param_card_1.dat
# 00:06 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_1.dat
# 00:06 madminer.core        INFO      Log file:                run_1.log
# 00:06 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_1.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_1.dat
# 00:06 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 00:20 madminer.core        INFO    Run 2
# 00:20 madminer.core        INFO      Sampling from benchmark: sm
# 00:20 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 00:20 madminer.core        INFO      Original Pythia8 card:   None
# 00:20 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_2.dat
# 00:20 madminer.core        INFO      Copied Pythia8 card:     None
# 00:20 madminer.core        INFO      Param card:              /madminer/cards/param_card_2.dat
# 00:20 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_2.dat
# 00:20 madminer.core        INFO      Log file:                run_2.log
# 00:20 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_2.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_2.dat
# 00:20 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 00:35 madminer.core        INFO    Run 3
# 00:35 madminer.core        INFO      Sampling from benchmark: sm
# 00:35 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 00:35 madminer.core        INFO      Original Pythia8 card:   None
# 00:35 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_3.dat
# 00:35 madminer.core        INFO      Copied Pythia8 card:     None
# 00:35 madminer.core        INFO      Param card:              /madminer/cards/param_card_3.dat
# 00:35 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_3.dat
# 00:35 madminer.core        INFO      Log file:                run_3.log
# 00:35 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_3.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_3.dat
# 00:35 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 00:49 madminer.core        INFO    Run 4
# 00:49 madminer.core        INFO      Sampling from benchmark: sm
# 00:49 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 00:49 madminer.core        INFO      Original Pythia8 card:   None
# 00:49 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_4.dat
# 00:49 madminer.core        INFO      Copied Pythia8 card:     None
# 00:49 madminer.core        INFO      Param card:              /madminer/cards/param_card_4.dat
# 00:49 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_4.dat
# 00:49 madminer.core        INFO      Log file:                run_4.log
# 00:49 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_4.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_4.dat
# 00:49 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 01:02 madminer.core        INFO    Run 5
# 01:02 madminer.core        INFO      Sampling from benchmark: sm
# 01:02 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 01:02 madminer.core        INFO      Original Pythia8 card:   None
# 01:02 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_5.dat
# 01:02 madminer.core        INFO      Copied Pythia8 card:     None
# 01:02 madminer.core        INFO      Param card:              /madminer/cards/param_card_5.dat
# 01:02 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_5.dat
# 01:02 madminer.core        INFO      Log file:                run_5.log
# 01:02 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_5.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_5.dat
# 01:02 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 01:16 madminer.core        INFO    Run 6
# 01:16 madminer.core        INFO      Sampling from benchmark: sm
# 01:16 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 01:16 madminer.core        INFO      Original Pythia8 card:   None
# 01:16 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_6.dat
# 01:16 madminer.core        INFO      Copied Pythia8 card:     None
# 01:16 madminer.core        INFO      Param card:              /madminer/cards/param_card_6.dat
# 01:16 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_6.dat
# 01:16 madminer.core        INFO      Log file:                run_6.log
# 01:16 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_6.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_6.dat
# 01:16 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 01:29 madminer.core        INFO    Run 7
# 01:29 madminer.core        INFO      Sampling from benchmark: sm
# 01:29 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 01:29 madminer.core        INFO      Original Pythia8 card:   None
# 01:29 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_7.dat
# 01:29 madminer.core        INFO      Copied Pythia8 card:     None
# 01:29 madminer.core        INFO      Param card:              /madminer/cards/param_card_7.dat
# 01:29 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_7.dat
# 01:29 madminer.core        INFO      Log file:                run_7.log
# 01:29 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_7.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_7.dat
# 01:29 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 01:43 madminer.core        INFO    Run 8
# 01:43 madminer.core        INFO      Sampling from benchmark: sm
# 01:43 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 01:43 madminer.core        INFO      Original Pythia8 card:   None
# 01:43 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_8.dat
# 01:43 madminer.core        INFO      Copied Pythia8 card:     None
# 01:43 madminer.core        INFO      Param card:              /madminer/cards/param_card_8.dat
# 01:43 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_8.dat
# 01:43 madminer.core        INFO      Log file:                run_8.log
# 01:43 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_8.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_8.dat
# 01:43 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 01:56 madminer.core        INFO    Run 9
# 01:56 madminer.core        INFO      Sampling from benchmark: sm
# 01:56 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 01:56 madminer.core        INFO      Original Pythia8 card:   None
# 01:56 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_9.dat
# 01:56 madminer.core        INFO      Copied Pythia8 card:     None
# 01:56 madminer.core        INFO      Param card:              /madminer/cards/param_card_9.dat
# 01:56 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_9.dat
# 01:56 madminer.core        INFO      Log file:                run_9.log
# 01:56 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_9.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_9.dat
# 01:56 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 02:09 madminer.core        INFO    Run 10
# 02:09 madminer.core        INFO      Sampling from benchmark: sm
# 02:09 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 02:09 madminer.core        INFO      Original Pythia8 card:   None
# 02:09 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_10.dat
# 02:09 madminer.core        INFO      Copied Pythia8 card:     None
# 02:09 madminer.core        INFO      Param card:              /madminer/cards/param_card_10.dat
# 02:09 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_10.dat
# 02:09 madminer.core        INFO      Log file:                run_10.log
# 02:09 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_10.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_10.dat
# 02:09 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 02:22 madminer.core        INFO    Run 11
# 02:22 madminer.core        INFO      Sampling from benchmark: sm
# 02:22 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 02:22 madminer.core        INFO      Original Pythia8 card:   None
# 02:22 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_11.dat
# 02:22 madminer.core        INFO      Copied Pythia8 card:     None
# 02:22 madminer.core        INFO      Param card:              /madminer/cards/param_card_11.dat
# 02:22 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_11.dat
# 02:22 madminer.core        INFO      Log file:                run_11.log
# 02:22 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_11.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_11.dat
# 02:22 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 02:35 madminer.core        INFO    Run 12
# 02:35 madminer.core        INFO      Sampling from benchmark: sm
# 02:35 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 02:35 madminer.core        INFO      Original Pythia8 card:   None
# 02:35 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_12.dat
# 02:35 madminer.core        INFO      Copied Pythia8 card:     None
# 02:35 madminer.core        INFO      Param card:              /madminer/cards/param_card_12.dat
# 02:35 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_12.dat
# 02:35 madminer.core        INFO      Log file:                run_12.log
# 02:35 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_12.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_12.dat
# 02:35 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 02:48 madminer.core        INFO    Run 13
# 02:48 madminer.core        INFO      Sampling from benchmark: sm
# 02:48 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 02:48 madminer.core        INFO      Original Pythia8 card:   None
# 02:48 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_13.dat
# 02:48 madminer.core        INFO      Copied Pythia8 card:     None
# 02:48 madminer.core        INFO      Param card:              /madminer/cards/param_card_13.dat
# 02:48 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_13.dat
# 02:48 madminer.core        INFO      Log file:                run_13.log
# 02:48 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_13.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_13.dat
# 02:48 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 03:03 madminer.core        INFO    Run 14
# 03:03 madminer.core        INFO      Sampling from benchmark: sm
# 03:03 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 03:03 madminer.core        INFO      Original Pythia8 card:   None
# 03:03 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_14.dat
# 03:03 madminer.core        INFO      Copied Pythia8 card:     None
# 03:03 madminer.core        INFO      Param card:              /madminer/cards/param_card_14.dat
# 03:03 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_14.dat
# 03:03 madminer.core        INFO      Log file:                run_14.log
# 03:03 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_14.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_14.dat
# 03:03 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 03:16 madminer.core        INFO    Run 15
# 03:16 madminer.core        INFO      Sampling from benchmark: sm
# 03:16 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 03:16 madminer.core        INFO      Original Pythia8 card:   None
# 03:16 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_15.dat
# 03:16 madminer.core        INFO      Copied Pythia8 card:     None
# 03:16 madminer.core        INFO      Param card:              /madminer/cards/param_card_15.dat
# 03:16 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_15.dat
# 03:16 madminer.core        INFO      Log file:                run_15.log
# 03:16 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_15.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_15.dat
# 03:16 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 03:29 madminer.core        INFO    Run 16
# 03:29 madminer.core        INFO      Sampling from benchmark: sm
# 03:29 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 03:29 madminer.core        INFO      Original Pythia8 card:   None
# 03:29 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_16.dat
# 03:29 madminer.core        INFO      Copied Pythia8 card:     None
# 03:29 madminer.core        INFO      Param card:              /madminer/cards/param_card_16.dat
# 03:29 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_16.dat
# 03:29 madminer.core        INFO      Log file:                run_16.log
# 03:29 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_16.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_16.dat
# 03:29 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 03:50 madminer.core        INFO    Run 17
# 03:50 madminer.core        INFO      Sampling from benchmark: sm
# 03:50 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 03:50 madminer.core        INFO      Original Pythia8 card:   None
# 03:50 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_17.dat
# 03:50 madminer.core        INFO      Copied Pythia8 card:     None
# 03:50 madminer.core        INFO      Param card:              /madminer/cards/param_card_17.dat
# 03:50 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_17.dat
# 03:50 madminer.core        INFO      Log file:                run_17.log
# 03:50 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_17.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_17.dat
# 03:50 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 04:03 madminer.core        INFO    Run 18
# 04:03 madminer.core        INFO      Sampling from benchmark: sm
# 04:03 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 04:03 madminer.core        INFO      Original Pythia8 card:   None
# 04:03 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_18.dat
# 04:03 madminer.core        INFO      Copied Pythia8 card:     None
# 04:03 madminer.core        INFO      Param card:              /madminer/cards/param_card_18.dat
# 04:03 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_18.dat
# 04:03 madminer.core        INFO      Log file:                run_18.log
# 04:03 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_18.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_18.dat
# 04:03 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 04:19 madminer.core        INFO    Run 19
# 04:19 madminer.core        INFO      Sampling from benchmark: sm
# 04:19 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 04:19 madminer.core        INFO      Original Pythia8 card:   None
# 04:19 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_19.dat
# 04:19 madminer.core        INFO      Copied Pythia8 card:     None
# 04:19 madminer.core        INFO      Param card:              /madminer/cards/param_card_19.dat
# 04:19 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_19.dat
# 04:19 madminer.core        INFO      Log file:                run_19.log
# 04:19 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_19.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_19.dat
# 04:19 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 04:32 madminer.core        INFO    Run 20
# 04:32 madminer.core        INFO      Sampling from benchmark: sm
# 04:32 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 04:32 madminer.core        INFO      Original Pythia8 card:   None
# 04:32 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_20.dat
# 04:32 madminer.core        INFO      Copied Pythia8 card:     None
# 04:32 madminer.core        INFO      Param card:              /madminer/cards/param_card_20.dat
# 04:32 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_20.dat
# 04:32 madminer.core        INFO      Log file:                run_20.log
# 04:32 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_20.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_20.dat
# 04:32 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 04:48 madminer.core        INFO    Run 21
# 04:48 madminer.core        INFO      Sampling from benchmark: sm
# 04:48 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 04:48 madminer.core        INFO      Original Pythia8 card:   None
# 04:48 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_21.dat
# 04:48 madminer.core        INFO      Copied Pythia8 card:     None
# 04:48 madminer.core        INFO      Param card:              /madminer/cards/param_card_21.dat
# 04:48 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_21.dat
# 04:48 madminer.core        INFO      Log file:                run_21.log
# 04:48 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_21.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_21.dat
# 04:48 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 05:02 madminer.core        INFO    Run 22
# 05:02 madminer.core        INFO      Sampling from benchmark: sm
# 05:02 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 05:02 madminer.core        INFO      Original Pythia8 card:   None
# 05:02 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_22.dat
# 05:02 madminer.core        INFO      Copied Pythia8 card:     None
# 05:02 madminer.core        INFO      Param card:              /madminer/cards/param_card_22.dat
# 05:02 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_22.dat
# 05:02 madminer.core        INFO      Log file:                run_22.log
# 05:02 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_22.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_22.dat
# 05:02 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 05:18 madminer.core        INFO    Run 23
# 05:18 madminer.core        INFO      Sampling from benchmark: sm
# 05:18 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 05:18 madminer.core        INFO      Original Pythia8 card:   None
# 05:18 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_23.dat
# 05:18 madminer.core        INFO      Copied Pythia8 card:     None
# 05:18 madminer.core        INFO      Param card:              /madminer/cards/param_card_23.dat
# 05:18 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_23.dat
# 05:18 madminer.core        INFO      Log file:                run_23.log
# 05:18 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_23.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_23.dat
# 05:18 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 05:33 madminer.core        INFO    Run 24
# 05:33 madminer.core        INFO      Sampling from benchmark: sm
# 05:33 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 05:33 madminer.core        INFO      Original Pythia8 card:   None
# 05:33 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_24.dat
# 05:33 madminer.core        INFO      Copied Pythia8 card:     None
# 05:33 madminer.core        INFO      Param card:              /madminer/cards/param_card_24.dat
# 05:33 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_24.dat
# 05:33 madminer.core        INFO      Log file:                run_24.log
# 05:33 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_24.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_24.dat
# 05:33 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 05:46 madminer.core        INFO    Run 25
# 05:46 madminer.core        INFO      Sampling from benchmark: sm
# 05:46 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 05:46 madminer.core        INFO      Original Pythia8 card:   None
# 05:46 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_25.dat
# 05:46 madminer.core        INFO      Copied Pythia8 card:     None
# 05:46 madminer.core        INFO      Param card:              /madminer/cards/param_card_25.dat
# 05:46 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_25.dat
# 05:46 madminer.core        INFO      Log file:                run_25.log
# 05:46 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_25.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_25.dat
# 05:46 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 06:01 madminer.core        INFO    Run 26
# 06:01 madminer.core        INFO      Sampling from benchmark: sm
# 06:01 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 06:01 madminer.core        INFO      Original Pythia8 card:   None
# 06:01 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_26.dat
# 06:01 madminer.core        INFO      Copied Pythia8 card:     None
# 06:01 madminer.core        INFO      Param card:              /madminer/cards/param_card_26.dat
# 06:01 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_26.dat
# 06:01 madminer.core        INFO      Log file:                run_26.log
# 06:01 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_26.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_26.dat
# 06:01 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 06:14 madminer.core        INFO    Run 27
# 06:14 madminer.core        INFO      Sampling from benchmark: sm
# 06:14 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 06:14 madminer.core        INFO      Original Pythia8 card:   None
# 06:14 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_27.dat
# 06:14 madminer.core        INFO      Copied Pythia8 card:     None
# 06:14 madminer.core        INFO      Param card:              /madminer/cards/param_card_27.dat
# 06:14 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_27.dat
# 06:14 madminer.core        INFO      Log file:                run_27.log
# 06:14 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_27.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_27.dat
# 06:14 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 06:28 madminer.core        INFO    Run 28
# 06:28 madminer.core        INFO      Sampling from benchmark: sm
# 06:28 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 06:28 madminer.core        INFO      Original Pythia8 card:   None
# 06:28 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_28.dat
# 06:28 madminer.core        INFO      Copied Pythia8 card:     None
# 06:28 madminer.core        INFO      Param card:              /madminer/cards/param_card_28.dat
# 06:28 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_28.dat
# 06:28 madminer.core        INFO      Log file:                run_28.log
# 06:28 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_28.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_28.dat
# 06:28 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 06:44 madminer.core        INFO    Run 29
# 06:44 madminer.core        INFO      Sampling from benchmark: sm
# 06:44 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 06:44 madminer.core        INFO      Original Pythia8 card:   None
# 06:44 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_29.dat
# 06:44 madminer.core        INFO      Copied Pythia8 card:     None
# 06:44 madminer.core        INFO      Param card:              /madminer/cards/param_card_29.dat
# 06:44 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_29.dat
# 06:44 madminer.core        INFO      Log file:                run_29.log
# 06:44 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_29.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_29.dat
# 06:44 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 06:59 madminer.core        INFO    Run 30
# 06:59 madminer.core        INFO      Sampling from benchmark: sm
# 06:59 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 06:59 madminer.core        INFO      Original Pythia8 card:   None
# 06:59 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_30.dat
# 06:59 madminer.core        INFO      Copied Pythia8 card:     None
# 06:59 madminer.core        INFO      Param card:              /madminer/cards/param_card_30.dat
# 06:59 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_30.dat
# 06:59 madminer.core        INFO      Log file:                run_30.log
# 06:59 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_30.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_30.dat
# 06:59 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 07:14 madminer.core        INFO    Run 31
# 07:14 madminer.core        INFO      Sampling from benchmark: sm
# 07:14 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 07:14 madminer.core        INFO      Original Pythia8 card:   None
# 07:14 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_31.dat
# 07:14 madminer.core        INFO      Copied Pythia8 card:     None
# 07:14 madminer.core        INFO      Param card:              /madminer/cards/param_card_31.dat
# 07:14 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_31.dat
# 07:14 madminer.core        INFO      Log file:                run_31.log
# 07:14 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_31.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_31.dat
# 07:14 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 07:28 madminer.core        INFO    Run 32
# 07:28 madminer.core        INFO      Sampling from benchmark: sm
# 07:28 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 07:28 madminer.core        INFO      Original Pythia8 card:   None
# 07:28 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_32.dat
# 07:28 madminer.core        INFO      Copied Pythia8 card:     None
# 07:28 madminer.core        INFO      Param card:              /madminer/cards/param_card_32.dat
# 07:28 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_32.dat
# 07:28 madminer.core        INFO      Log file:                run_32.log
# 07:28 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_32.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_32.dat
# 07:28 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 07:42 madminer.core        INFO    Run 33
# 07:42 madminer.core        INFO      Sampling from benchmark: sm
# 07:42 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 07:42 madminer.core        INFO      Original Pythia8 card:   None
# 07:42 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_33.dat
# 07:42 madminer.core        INFO      Copied Pythia8 card:     None
# 07:42 madminer.core        INFO      Param card:              /madminer/cards/param_card_33.dat
# 07:42 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_33.dat
# 07:42 madminer.core        INFO      Log file:                run_33.log
# 07:42 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_33.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_33.dat
# 07:42 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 07:57 madminer.core        INFO    Run 34
# 07:57 madminer.core        INFO      Sampling from benchmark: sm
# 07:57 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 07:57 madminer.core        INFO      Original Pythia8 card:   None
# 07:57 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_34.dat
# 07:57 madminer.core        INFO      Copied Pythia8 card:     None
# 07:57 madminer.core        INFO      Param card:              /madminer/cards/param_card_34.dat
# 07:57 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_34.dat
# 07:57 madminer.core        INFO      Log file:                run_34.log
# 07:57 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_34.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_34.dat
# 07:57 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 08:10 madminer.core        INFO    Run 35
# 08:10 madminer.core        INFO      Sampling from benchmark: sm
# 08:10 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 08:10 madminer.core        INFO      Original Pythia8 card:   None
# 08:10 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_35.dat
# 08:10 madminer.core        INFO      Copied Pythia8 card:     None
# 08:10 madminer.core        INFO      Param card:              /madminer/cards/param_card_35.dat
# 08:10 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_35.dat
# 08:10 madminer.core        INFO      Log file:                run_35.log
# 08:10 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_35.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_35.dat
# 08:10 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 08:24 madminer.core        INFO    Run 36
# 08:24 madminer.core        INFO      Sampling from benchmark: sm
# 08:24 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 08:24 madminer.core        INFO      Original Pythia8 card:   None
# 08:24 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_36.dat
# 08:24 madminer.core        INFO      Copied Pythia8 card:     None
# 08:24 madminer.core        INFO      Param card:              /madminer/cards/param_card_36.dat
# 08:24 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_36.dat
# 08:24 madminer.core        INFO      Log file:                run_36.log
# 08:24 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_36.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_36.dat
# 08:24 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 08:37 madminer.core        INFO    Run 37
# 08:37 madminer.core        INFO      Sampling from benchmark: sm
# 08:37 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 08:37 madminer.core        INFO      Original Pythia8 card:   None
# 08:37 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_37.dat
# 08:37 madminer.core        INFO      Copied Pythia8 card:     None
# 08:37 madminer.core        INFO      Param card:              /madminer/cards/param_card_37.dat
# 08:37 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_37.dat
# 08:37 madminer.core        INFO      Log file:                run_37.log
# 08:37 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_37.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_37.dat
# 08:37 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 08:52 madminer.core        INFO    Run 38
# 08:52 madminer.core        INFO      Sampling from benchmark: sm
# 08:52 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 08:52 madminer.core        INFO      Original Pythia8 card:   None
# 08:52 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_38.dat
# 08:52 madminer.core        INFO      Copied Pythia8 card:     None
# 08:52 madminer.core        INFO      Param card:              /madminer/cards/param_card_38.dat
# 08:52 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_38.dat
# 08:52 madminer.core        INFO      Log file:                run_38.log
# 08:52 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_38.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_38.dat
# 08:52 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 09:05 madminer.core        INFO    Run 39
# 09:05 madminer.core        INFO      Sampling from benchmark: sm
# 09:05 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 09:05 madminer.core        INFO      Original Pythia8 card:   None
# 09:05 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_39.dat
# 09:05 madminer.core        INFO      Copied Pythia8 card:     None
# 09:05 madminer.core        INFO      Param card:              /madminer/cards/param_card_39.dat
# 09:05 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_39.dat
# 09:05 madminer.core        INFO      Log file:                run_39.log
# 09:05 madminer.core        INFO    Creating param and reweight cards in ./wph_e_smeftsim//madminer/cards/param_card_39.dat, ./wph_e_smeftsim//madminer/cards/reweight_card_39.dat
# 09:05 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wph_e_smeftsim
# 09:18 madminer.core        INFO    Finished running MadGraph! Please check that events were succesfully generated in the following folders:
#
# ./wph_e_smeftsim/Events/run_01
# ./wph_e_smeftsim/Events/run_02
# ./wph_e_smeftsim/Events/run_03
# ./wph_e_smeftsim/Events/run_04
# ./wph_e_smeftsim/Events/run_05
# ./wph_e_smeftsim/Events/run_06
# ./wph_e_smeftsim/Events/run_07
# ./wph_e_smeftsim/Events/run_08
# ./wph_e_smeftsim/Events/run_09
# ./wph_e_smeftsim/Events/run_10
# ./wph_e_smeftsim/Events/run_11
# ./wph_e_smeftsim/Events/run_12
# ./wph_e_smeftsim/Events/run_13
# ./wph_e_smeftsim/Events/run_14
# ./wph_e_smeftsim/Events/run_15
# ./wph_e_smeftsim/Events/run_16
# ./wph_e_smeftsim/Events/run_17
# ./wph_e_smeftsim/Events/run_18
# ./wph_e_smeftsim/Events/run_19
# ./wph_e_smeftsim/Events/run_20
# ./wph_e_smeftsim/Events/run_21
# ./wph_e_smeftsim/Events/run_22
# ./wph_e_smeftsim/Events/run_23
# ./wph_e_smeftsim/Events/run_24
# ./wph_e_smeftsim/Events/run_25
# ./wph_e_smeftsim/Events/run_26
# ./wph_e_smeftsim/Events/run_27
# ./wph_e_smeftsim/Events/run_28
# ./wph_e_smeftsim/Events/run_29
# ./wph_e_smeftsim/Events/run_30
# ./wph_e_smeftsim/Events/run_31
# ./wph_e_smeftsim/Events/run_32
# ./wph_e_smeftsim/Events/run_33
# ./wph_e_smeftsim/Events/run_34
# ./wph_e_smeftsim/Events/run_35
# ./wph_e_smeftsim/Events/run_36
# ./wph_e_smeftsim/Events/run_37
# ./wph_e_smeftsim/Events/run_38
# ./wph_e_smeftsim/Events/run_39
# ./wph_e_smeftsim/Events/run_40

# %% [markdown]
# ## 3. $W^-(\mu^-\bar{\nu}_{\mu})H(b\bar{b})$

# %%
miner.run_multiple(
    mg_directory=mg_dir,
    log_directory='logs/wmh_mu_smeftsim',
    mg_process_directory='./signal_samples/wmh_mu_smeftsim',
    proc_card_file='../cards/signal_processes/proc_card_wmh_mu_smeftsim.dat',
    param_card_template_file='../cards/param_card_template_smeftsim.dat',
    run_card_files=['../cards/run_card_wh_parton.dat' for i in range(nrun)],
    sample_benchmarks=['sm'],
    initial_command=None
)
# Out:
# 09:18 madminer.utils.inter INFO    Generating MadGraph process folder from ../cards/signal_processes/proc_card_wmh_mu_smeftsim.dat at ./wmh_mu_smeftsim
# 09:18 madminer.core        INFO    Run 0
# 09:18 madminer.core        INFO      Sampling from benchmark: sm
# 09:18 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 09:18 madminer.core        INFO      Original Pythia8 card:   None
# 09:18 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_0.dat
# 09:18 madminer.core        INFO      Copied Pythia8 card:     None
# 09:18 madminer.core        INFO      Param card:              /madminer/cards/param_card_0.dat
# 09:18 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_0.dat
# 09:18 madminer.core        INFO      Log file:                run_0.log
# 09:18 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_0.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_0.dat
# 09:18 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 09:31 madminer.core        INFO    Run 1
# 09:31 madminer.core        INFO      Sampling from benchmark: sm
# 09:31 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 09:31 madminer.core        INFO      Original Pythia8 card:   None
# 09:31 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_1.dat
# 09:31 madminer.core        INFO      Copied Pythia8 card:     None
# 09:31 madminer.core        INFO      Param card:              /madminer/cards/param_card_1.dat
# 09:31 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_1.dat
# 09:31 madminer.core        INFO      Log file:                run_1.log
# 09:31 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_1.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_1.dat
# 09:31 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 09:44 madminer.core        INFO    Run 2
# 09:44 madminer.core        INFO      Sampling from benchmark: sm
# 09:44 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 09:44 madminer.core        INFO      Original Pythia8 card:   None
# 09:44 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_2.dat
# 09:44 madminer.core        INFO      Copied Pythia8 card:     None
# 09:44 madminer.core        INFO      Param card:              /madminer/cards/param_card_2.dat
# 09:44 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_2.dat
# 09:44 madminer.core        INFO      Log file:                run_2.log
# 09:44 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_2.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_2.dat
# 09:44 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 09:56 madminer.core        INFO    Run 3
# 09:56 madminer.core        INFO      Sampling from benchmark: sm
# 09:56 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 09:56 madminer.core        INFO      Original Pythia8 card:   None
# 09:56 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_3.dat
# 09:56 madminer.core        INFO      Copied Pythia8 card:     None
# 09:56 madminer.core        INFO      Param card:              /madminer/cards/param_card_3.dat
# 09:56 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_3.dat
# 09:56 madminer.core        INFO      Log file:                run_3.log
# 09:56 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_3.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_3.dat
# 09:56 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 10:11 madminer.core        INFO    Run 4
# 10:11 madminer.core        INFO      Sampling from benchmark: sm
# 10:11 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 10:11 madminer.core        INFO      Original Pythia8 card:   None
# 10:11 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_4.dat
# 10:11 madminer.core        INFO      Copied Pythia8 card:     None
# 10:11 madminer.core        INFO      Param card:              /madminer/cards/param_card_4.dat
# 10:11 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_4.dat
# 10:11 madminer.core        INFO      Log file:                run_4.log
# 10:11 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_4.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_4.dat
# 10:11 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 10:25 madminer.core        INFO    Run 5
# 10:25 madminer.core        INFO      Sampling from benchmark: sm
# 10:25 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 10:25 madminer.core        INFO      Original Pythia8 card:   None
# 10:25 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_5.dat
# 10:25 madminer.core        INFO      Copied Pythia8 card:     None
# 10:25 madminer.core        INFO      Param card:              /madminer/cards/param_card_5.dat
# 10:25 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_5.dat
# 10:25 madminer.core        INFO      Log file:                run_5.log
# 10:25 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_5.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_5.dat
# 10:25 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 10:41 madminer.core        INFO    Run 6
# 10:41 madminer.core        INFO      Sampling from benchmark: sm
# 10:41 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 10:41 madminer.core        INFO      Original Pythia8 card:   None
# 10:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_6.dat
# 10:41 madminer.core        INFO      Copied Pythia8 card:     None
# 10:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_6.dat
# 10:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_6.dat
# 10:41 madminer.core        INFO      Log file:                run_6.log
# 10:41 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_6.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_6.dat
# 10:41 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 10:56 madminer.core        INFO    Run 7
# 10:56 madminer.core        INFO      Sampling from benchmark: sm
# 10:56 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 10:56 madminer.core        INFO      Original Pythia8 card:   None
# 10:56 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_7.dat
# 10:56 madminer.core        INFO      Copied Pythia8 card:     None
# 10:56 madminer.core        INFO      Param card:              /madminer/cards/param_card_7.dat
# 10:56 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_7.dat
# 10:56 madminer.core        INFO      Log file:                run_7.log
# 10:56 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_7.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_7.dat
# 10:56 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 11:10 madminer.core        INFO    Run 8
# 11:10 madminer.core        INFO      Sampling from benchmark: sm
# 11:10 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 11:10 madminer.core        INFO      Original Pythia8 card:   None
# 11:10 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_8.dat
# 11:10 madminer.core        INFO      Copied Pythia8 card:     None
# 11:10 madminer.core        INFO      Param card:              /madminer/cards/param_card_8.dat
# 11:10 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_8.dat
# 11:10 madminer.core        INFO      Log file:                run_8.log
# 11:10 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_8.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_8.dat
# 11:10 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 11:25 madminer.core        INFO    Run 9
# 11:25 madminer.core        INFO      Sampling from benchmark: sm
# 11:25 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 11:25 madminer.core        INFO      Original Pythia8 card:   None
# 11:25 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_9.dat
# 11:25 madminer.core        INFO      Copied Pythia8 card:     None
# 11:25 madminer.core        INFO      Param card:              /madminer/cards/param_card_9.dat
# 11:25 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_9.dat
# 11:25 madminer.core        INFO      Log file:                run_9.log
# 11:25 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_9.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_9.dat
# 11:25 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 11:39 madminer.core        INFO    Run 10
# 11:39 madminer.core        INFO      Sampling from benchmark: sm
# 11:39 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 11:39 madminer.core        INFO      Original Pythia8 card:   None
# 11:39 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_10.dat
# 11:39 madminer.core        INFO      Copied Pythia8 card:     None
# 11:39 madminer.core        INFO      Param card:              /madminer/cards/param_card_10.dat
# 11:39 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_10.dat
# 11:39 madminer.core        INFO      Log file:                run_10.log
# 11:39 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_10.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_10.dat
# 11:39 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 11:56 madminer.core        INFO    Run 11
# 11:56 madminer.core        INFO      Sampling from benchmark: sm
# 11:56 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 11:56 madminer.core        INFO      Original Pythia8 card:   None
# 11:56 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_11.dat
# 11:56 madminer.core        INFO      Copied Pythia8 card:     None
# 11:56 madminer.core        INFO      Param card:              /madminer/cards/param_card_11.dat
# 11:56 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_11.dat
# 11:56 madminer.core        INFO      Log file:                run_11.log
# 11:56 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_11.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_11.dat
# 11:56 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 12:09 madminer.core        INFO    Run 12
# 12:09 madminer.core        INFO      Sampling from benchmark: sm
# 12:09 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 12:09 madminer.core        INFO      Original Pythia8 card:   None
# 12:09 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_12.dat
# 12:09 madminer.core        INFO      Copied Pythia8 card:     None
# 12:09 madminer.core        INFO      Param card:              /madminer/cards/param_card_12.dat
# 12:09 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_12.dat
# 12:09 madminer.core        INFO      Log file:                run_12.log
# 12:09 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_12.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_12.dat
# 12:09 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 12:22 madminer.core        INFO    Run 13
# 12:22 madminer.core        INFO      Sampling from benchmark: sm
# 12:22 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 12:22 madminer.core        INFO      Original Pythia8 card:   None
# 12:22 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_13.dat
# 12:22 madminer.core        INFO      Copied Pythia8 card:     None
# 12:22 madminer.core        INFO      Param card:              /madminer/cards/param_card_13.dat
# 12:22 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_13.dat
# 12:22 madminer.core        INFO      Log file:                run_13.log
# 12:22 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_13.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_13.dat
# 12:22 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 12:35 madminer.core        INFO    Run 14
# 12:35 madminer.core        INFO      Sampling from benchmark: sm
# 12:35 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 12:35 madminer.core        INFO      Original Pythia8 card:   None
# 12:35 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_14.dat
# 12:35 madminer.core        INFO      Copied Pythia8 card:     None
# 12:35 madminer.core        INFO      Param card:              /madminer/cards/param_card_14.dat
# 12:35 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_14.dat
# 12:35 madminer.core        INFO      Log file:                run_14.log
# 12:35 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_14.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_14.dat
# 12:35 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 12:49 madminer.core        INFO    Run 15
# 12:49 madminer.core        INFO      Sampling from benchmark: sm
# 12:49 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 12:49 madminer.core        INFO      Original Pythia8 card:   None
# 12:49 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_15.dat
# 12:49 madminer.core        INFO      Copied Pythia8 card:     None
# 12:49 madminer.core        INFO      Param card:              /madminer/cards/param_card_15.dat
# 12:49 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_15.dat
# 12:49 madminer.core        INFO      Log file:                run_15.log
# 12:49 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_15.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_15.dat
# 12:49 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 13:02 madminer.core        INFO    Run 16
# 13:02 madminer.core        INFO      Sampling from benchmark: sm
# 13:02 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 13:02 madminer.core        INFO      Original Pythia8 card:   None
# 13:02 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_16.dat
# 13:02 madminer.core        INFO      Copied Pythia8 card:     None
# 13:02 madminer.core        INFO      Param card:              /madminer/cards/param_card_16.dat
# 13:02 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_16.dat
# 13:02 madminer.core        INFO      Log file:                run_16.log
# 13:02 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_16.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_16.dat
# 13:02 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 13:15 madminer.core        INFO    Run 17
# 13:15 madminer.core        INFO      Sampling from benchmark: sm
# 13:15 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 13:15 madminer.core        INFO      Original Pythia8 card:   None
# 13:15 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_17.dat
# 13:15 madminer.core        INFO      Copied Pythia8 card:     None
# 13:15 madminer.core        INFO      Param card:              /madminer/cards/param_card_17.dat
# 13:15 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_17.dat
# 13:15 madminer.core        INFO      Log file:                run_17.log
# 13:15 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_17.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_17.dat
# 13:15 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 13:29 madminer.core        INFO    Run 18
# 13:29 madminer.core        INFO      Sampling from benchmark: sm
# 13:29 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 13:29 madminer.core        INFO      Original Pythia8 card:   None
# 13:29 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_18.dat
# 13:29 madminer.core        INFO      Copied Pythia8 card:     None
# 13:29 madminer.core        INFO      Param card:              /madminer/cards/param_card_18.dat
# 13:29 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_18.dat
# 13:29 madminer.core        INFO      Log file:                run_18.log
# 13:29 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_18.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_18.dat
# 13:29 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 13:42 madminer.core        INFO    Run 19
# 13:42 madminer.core        INFO      Sampling from benchmark: sm
# 13:42 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 13:42 madminer.core        INFO      Original Pythia8 card:   None
# 13:42 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_19.dat
# 13:42 madminer.core        INFO      Copied Pythia8 card:     None
# 13:42 madminer.core        INFO      Param card:              /madminer/cards/param_card_19.dat
# 13:42 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_19.dat
# 13:42 madminer.core        INFO      Log file:                run_19.log
# 13:42 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_19.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_19.dat
# 13:42 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 13:55 madminer.core        INFO    Run 20
# 13:55 madminer.core        INFO      Sampling from benchmark: sm
# 13:55 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 13:55 madminer.core        INFO      Original Pythia8 card:   None
# 13:55 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_20.dat
# 13:55 madminer.core        INFO      Copied Pythia8 card:     None
# 13:55 madminer.core        INFO      Param card:              /madminer/cards/param_card_20.dat
# 13:55 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_20.dat
# 13:55 madminer.core        INFO      Log file:                run_20.log
# 13:55 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_20.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_20.dat
# 13:55 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 14:09 madminer.core        INFO    Run 21
# 14:09 madminer.core        INFO      Sampling from benchmark: sm
# 14:09 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 14:09 madminer.core        INFO      Original Pythia8 card:   None
# 14:09 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_21.dat
# 14:09 madminer.core        INFO      Copied Pythia8 card:     None
# 14:09 madminer.core        INFO      Param card:              /madminer/cards/param_card_21.dat
# 14:09 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_21.dat
# 14:09 madminer.core        INFO      Log file:                run_21.log
# 14:09 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_21.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_21.dat
# 14:09 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 14:22 madminer.core        INFO    Run 22
# 14:22 madminer.core        INFO      Sampling from benchmark: sm
# 14:22 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 14:22 madminer.core        INFO      Original Pythia8 card:   None
# 14:22 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_22.dat
# 14:22 madminer.core        INFO      Copied Pythia8 card:     None
# 14:22 madminer.core        INFO      Param card:              /madminer/cards/param_card_22.dat
# 14:22 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_22.dat
# 14:22 madminer.core        INFO      Log file:                run_22.log
# 14:22 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_22.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_22.dat
# 14:22 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 14:35 madminer.core        INFO    Run 23
# 14:35 madminer.core        INFO      Sampling from benchmark: sm
# 14:35 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 14:35 madminer.core        INFO      Original Pythia8 card:   None
# 14:35 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_23.dat
# 14:35 madminer.core        INFO      Copied Pythia8 card:     None
# 14:35 madminer.core        INFO      Param card:              /madminer/cards/param_card_23.dat
# 14:35 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_23.dat
# 14:35 madminer.core        INFO      Log file:                run_23.log
# 14:35 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_23.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_23.dat
# 14:35 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 14:49 madminer.core        INFO    Run 24
# 14:49 madminer.core        INFO      Sampling from benchmark: sm
# 14:49 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 14:49 madminer.core        INFO      Original Pythia8 card:   None
# 14:49 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_24.dat
# 14:49 madminer.core        INFO      Copied Pythia8 card:     None
# 14:49 madminer.core        INFO      Param card:              /madminer/cards/param_card_24.dat
# 14:49 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_24.dat
# 14:49 madminer.core        INFO      Log file:                run_24.log
# 14:49 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_24.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_24.dat
# 14:49 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 15:04 madminer.core        INFO    Run 25
# 15:04 madminer.core        INFO      Sampling from benchmark: sm
# 15:04 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 15:04 madminer.core        INFO      Original Pythia8 card:   None
# 15:04 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_25.dat
# 15:04 madminer.core        INFO      Copied Pythia8 card:     None
# 15:04 madminer.core        INFO      Param card:              /madminer/cards/param_card_25.dat
# 15:04 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_25.dat
# 15:04 madminer.core        INFO      Log file:                run_25.log
# 15:04 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_25.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_25.dat
# 15:04 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 15:18 madminer.core        INFO    Run 26
# 15:18 madminer.core        INFO      Sampling from benchmark: sm
# 15:18 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 15:18 madminer.core        INFO      Original Pythia8 card:   None
# 15:18 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_26.dat
# 15:18 madminer.core        INFO      Copied Pythia8 card:     None
# 15:18 madminer.core        INFO      Param card:              /madminer/cards/param_card_26.dat
# 15:18 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_26.dat
# 15:18 madminer.core        INFO      Log file:                run_26.log
# 15:18 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_26.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_26.dat
# 15:18 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 15:32 madminer.core        INFO    Run 27
# 15:32 madminer.core        INFO      Sampling from benchmark: sm
# 15:32 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 15:32 madminer.core        INFO      Original Pythia8 card:   None
# 15:32 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_27.dat
# 15:32 madminer.core        INFO      Copied Pythia8 card:     None
# 15:32 madminer.core        INFO      Param card:              /madminer/cards/param_card_27.dat
# 15:32 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_27.dat
# 15:32 madminer.core        INFO      Log file:                run_27.log
# 15:32 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_27.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_27.dat
# 15:32 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 15:46 madminer.core        INFO    Run 28
# 15:46 madminer.core        INFO      Sampling from benchmark: sm
# 15:46 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 15:46 madminer.core        INFO      Original Pythia8 card:   None
# 15:46 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_28.dat
# 15:46 madminer.core        INFO      Copied Pythia8 card:     None
# 15:46 madminer.core        INFO      Param card:              /madminer/cards/param_card_28.dat
# 15:46 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_28.dat
# 15:46 madminer.core        INFO      Log file:                run_28.log
# 15:46 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_28.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_28.dat
# 15:46 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 16:01 madminer.core        INFO    Run 29
# 16:01 madminer.core        INFO      Sampling from benchmark: sm
# 16:01 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 16:01 madminer.core        INFO      Original Pythia8 card:   None
# 16:01 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_29.dat
# 16:01 madminer.core        INFO      Copied Pythia8 card:     None
# 16:01 madminer.core        INFO      Param card:              /madminer/cards/param_card_29.dat
# 16:01 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_29.dat
# 16:01 madminer.core        INFO      Log file:                run_29.log
# 16:01 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_29.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_29.dat
# 16:01 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 16:16 madminer.core        INFO    Run 30
# 16:16 madminer.core        INFO      Sampling from benchmark: sm
# 16:16 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 16:16 madminer.core        INFO      Original Pythia8 card:   None
# 16:16 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_30.dat
# 16:16 madminer.core        INFO      Copied Pythia8 card:     None
# 16:16 madminer.core        INFO      Param card:              /madminer/cards/param_card_30.dat
# 16:16 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_30.dat
# 16:16 madminer.core        INFO      Log file:                run_30.log
# 16:16 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_30.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_30.dat
# 16:16 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 16:29 madminer.core        INFO    Run 31
# 16:29 madminer.core        INFO      Sampling from benchmark: sm
# 16:29 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 16:29 madminer.core        INFO      Original Pythia8 card:   None
# 16:29 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_31.dat
# 16:29 madminer.core        INFO      Copied Pythia8 card:     None
# 16:29 madminer.core        INFO      Param card:              /madminer/cards/param_card_31.dat
# 16:29 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_31.dat
# 16:29 madminer.core        INFO      Log file:                run_31.log
# 16:29 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_31.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_31.dat
# 16:29 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 16:42 madminer.core        INFO    Run 32
# 16:42 madminer.core        INFO      Sampling from benchmark: sm
# 16:42 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 16:42 madminer.core        INFO      Original Pythia8 card:   None
# 16:42 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_32.dat
# 16:42 madminer.core        INFO      Copied Pythia8 card:     None
# 16:42 madminer.core        INFO      Param card:              /madminer/cards/param_card_32.dat
# 16:42 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_32.dat
# 16:42 madminer.core        INFO      Log file:                run_32.log
# 16:42 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_32.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_32.dat
# 16:42 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 16:55 madminer.core        INFO    Run 33
# 16:55 madminer.core        INFO      Sampling from benchmark: sm
# 16:55 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 16:55 madminer.core        INFO      Original Pythia8 card:   None
# 16:55 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_33.dat
# 16:55 madminer.core        INFO      Copied Pythia8 card:     None
# 16:55 madminer.core        INFO      Param card:              /madminer/cards/param_card_33.dat
# 16:55 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_33.dat
# 16:55 madminer.core        INFO      Log file:                run_33.log
# 16:55 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_33.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_33.dat
# 16:55 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 17:08 madminer.core        INFO    Run 34
# 17:08 madminer.core        INFO      Sampling from benchmark: sm
# 17:08 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 17:08 madminer.core        INFO      Original Pythia8 card:   None
# 17:08 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_34.dat
# 17:08 madminer.core        INFO      Copied Pythia8 card:     None
# 17:08 madminer.core        INFO      Param card:              /madminer/cards/param_card_34.dat
# 17:08 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_34.dat
# 17:08 madminer.core        INFO      Log file:                run_34.log
# 17:08 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_34.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_34.dat
# 17:08 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 17:21 madminer.core        INFO    Run 35
# 17:21 madminer.core        INFO      Sampling from benchmark: sm
# 17:21 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 17:21 madminer.core        INFO      Original Pythia8 card:   None
# 17:21 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_35.dat
# 17:21 madminer.core        INFO      Copied Pythia8 card:     None
# 17:21 madminer.core        INFO      Param card:              /madminer/cards/param_card_35.dat
# 17:21 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_35.dat
# 17:21 madminer.core        INFO      Log file:                run_35.log
# 17:21 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_35.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_35.dat
# 17:21 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 17:34 madminer.core        INFO    Run 36
# 17:34 madminer.core        INFO      Sampling from benchmark: sm
# 17:34 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 17:34 madminer.core        INFO      Original Pythia8 card:   None
# 17:34 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_36.dat
# 17:34 madminer.core        INFO      Copied Pythia8 card:     None
# 17:34 madminer.core        INFO      Param card:              /madminer/cards/param_card_36.dat
# 17:34 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_36.dat
# 17:34 madminer.core        INFO      Log file:                run_36.log
# 17:34 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_36.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_36.dat
# 17:34 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 17:47 madminer.core        INFO    Run 37
# 17:47 madminer.core        INFO      Sampling from benchmark: sm
# 17:47 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 17:47 madminer.core        INFO      Original Pythia8 card:   None
# 17:47 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_37.dat
# 17:47 madminer.core        INFO      Copied Pythia8 card:     None
# 17:47 madminer.core        INFO      Param card:              /madminer/cards/param_card_37.dat
# 17:47 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_37.dat
# 17:47 madminer.core        INFO      Log file:                run_37.log
# 17:47 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_37.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_37.dat
# 17:47 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 18:00 madminer.core        INFO    Run 38
# 18:00 madminer.core        INFO      Sampling from benchmark: sm
# 18:00 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 18:00 madminer.core        INFO      Original Pythia8 card:   None
# 18:00 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_38.dat
# 18:00 madminer.core        INFO      Copied Pythia8 card:     None
# 18:00 madminer.core        INFO      Param card:              /madminer/cards/param_card_38.dat
# 18:00 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_38.dat
# 18:00 madminer.core        INFO      Log file:                run_38.log
# 18:00 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_38.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_38.dat
# 18:00 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 18:14 madminer.core        INFO    Run 39
# 18:14 madminer.core        INFO      Sampling from benchmark: sm
# 18:14 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 18:14 madminer.core        INFO      Original Pythia8 card:   None
# 18:14 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_39.dat
# 18:14 madminer.core        INFO      Copied Pythia8 card:     None
# 18:14 madminer.core        INFO      Param card:              /madminer/cards/param_card_39.dat
# 18:14 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_39.dat
# 18:14 madminer.core        INFO      Log file:                run_39.log
# 18:14 madminer.core        INFO    Creating param and reweight cards in ./wmh_mu_smeftsim//madminer/cards/param_card_39.dat, ./wmh_mu_smeftsim//madminer/cards/reweight_card_39.dat
# 18:14 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_mu_smeftsim
# 18:28 madminer.core        INFO    Finished running MadGraph! Please check that events were succesfully generated in the following folders:
#
# ./wmh_mu_smeftsim/Events/run_01
# ./wmh_mu_smeftsim/Events/run_02
# ./wmh_mu_smeftsim/Events/run_03
# ./wmh_mu_smeftsim/Events/run_04
# ./wmh_mu_smeftsim/Events/run_05
# ./wmh_mu_smeftsim/Events/run_06
# ./wmh_mu_smeftsim/Events/run_07
# ./wmh_mu_smeftsim/Events/run_08
# ./wmh_mu_smeftsim/Events/run_09
# ./wmh_mu_smeftsim/Events/run_10
# ./wmh_mu_smeftsim/Events/run_11
# ./wmh_mu_smeftsim/Events/run_12
# ./wmh_mu_smeftsim/Events/run_13
# ./wmh_mu_smeftsim/Events/run_14
# ./wmh_mu_smeftsim/Events/run_15
# ./wmh_mu_smeftsim/Events/run_16
# ./wmh_mu_smeftsim/Events/run_17
# ./wmh_mu_smeftsim/Events/run_18
# ./wmh_mu_smeftsim/Events/run_19
# ./wmh_mu_smeftsim/Events/run_20
# ./wmh_mu_smeftsim/Events/run_21
# ./wmh_mu_smeftsim/Events/run_22
# ./wmh_mu_smeftsim/Events/run_23
# ./wmh_mu_smeftsim/Events/run_24
# ./wmh_mu_smeftsim/Events/run_25
# ./wmh_mu_smeftsim/Events/run_26
# ./wmh_mu_smeftsim/Events/run_27
# ./wmh_mu_smeftsim/Events/run_28
# ./wmh_mu_smeftsim/Events/run_29
# ./wmh_mu_smeftsim/Events/run_30
# ./wmh_mu_smeftsim/Events/run_31
# ./wmh_mu_smeftsim/Events/run_32
# ./wmh_mu_smeftsim/Events/run_33
# ./wmh_mu_smeftsim/Events/run_34
# ./wmh_mu_smeftsim/Events/run_35
# ./wmh_mu_smeftsim/Events/run_36
# ./wmh_mu_smeftsim/Events/run_37
# ./wmh_mu_smeftsim/Events/run_38
# ./wmh_mu_smeftsim/Events/run_39
# ./wmh_mu_smeftsim/Events/run_40

# %% [markdown]
# ## 4. $W^-(e^-\bar{\nu}_{e})H(b\bar{b})$

# %%
miner.run_multiple(
    mg_directory=mg_dir,
    log_directory='logs/wmh_e_smeftsim',
    mg_process_directory='./signal_samples/wmh_e_smeftsim',
    proc_card_file='../cards/signal_processes/proc_card_wmh_e_smeftsim.dat',
    param_card_template_file='../cards/param_card_template_smeftsim.dat',
    run_card_files=['../cards/run_card_wh_parton.dat' for i in range(nrun)],
    sample_benchmarks=['sm'],
    initial_command=None
)
# Out:
# 18:28 madminer.utils.inter INFO    Generating MadGraph process folder from ../cards/signal_processes/proc_card_wmh_e_smeftsim.dat at ./wmh_e_smeftsim
# 18:28 madminer.core        INFO    Run 0
# 18:28 madminer.core        INFO      Sampling from benchmark: sm
# 18:28 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 18:28 madminer.core        INFO      Original Pythia8 card:   None
# 18:28 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_0.dat
# 18:28 madminer.core        INFO      Copied Pythia8 card:     None
# 18:28 madminer.core        INFO      Param card:              /madminer/cards/param_card_0.dat
# 18:28 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_0.dat
# 18:28 madminer.core        INFO      Log file:                run_0.log
# 18:28 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_0.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_0.dat
# 18:28 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 18:42 madminer.core        INFO    Run 1
# 18:42 madminer.core        INFO      Sampling from benchmark: sm
# 18:42 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 18:42 madminer.core        INFO      Original Pythia8 card:   None
# 18:42 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_1.dat
# 18:42 madminer.core        INFO      Copied Pythia8 card:     None
# 18:42 madminer.core        INFO      Param card:              /madminer/cards/param_card_1.dat
# 18:42 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_1.dat
# 18:42 madminer.core        INFO      Log file:                run_1.log
# 18:42 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_1.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_1.dat
# 18:42 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 18:56 madminer.core        INFO    Run 2
# 18:56 madminer.core        INFO      Sampling from benchmark: sm
# 18:56 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 18:56 madminer.core        INFO      Original Pythia8 card:   None
# 18:56 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_2.dat
# 18:56 madminer.core        INFO      Copied Pythia8 card:     None
# 18:56 madminer.core        INFO      Param card:              /madminer/cards/param_card_2.dat
# 18:56 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_2.dat
# 18:56 madminer.core        INFO      Log file:                run_2.log
# 18:56 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_2.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_2.dat
# 18:56 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 19:10 madminer.core        INFO    Run 3
# 19:10 madminer.core        INFO      Sampling from benchmark: sm
# 19:10 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 19:10 madminer.core        INFO      Original Pythia8 card:   None
# 19:10 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_3.dat
# 19:10 madminer.core        INFO      Copied Pythia8 card:     None
# 19:10 madminer.core        INFO      Param card:              /madminer/cards/param_card_3.dat
# 19:10 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_3.dat
# 19:10 madminer.core        INFO      Log file:                run_3.log
# 19:10 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_3.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_3.dat
# 19:10 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 19:26 madminer.core        INFO    Run 4
# 19:26 madminer.core        INFO      Sampling from benchmark: sm
# 19:26 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 19:26 madminer.core        INFO      Original Pythia8 card:   None
# 19:26 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_4.dat
# 19:26 madminer.core        INFO      Copied Pythia8 card:     None
# 19:26 madminer.core        INFO      Param card:              /madminer/cards/param_card_4.dat
# 19:26 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_4.dat
# 19:26 madminer.core        INFO      Log file:                run_4.log
# 19:26 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_4.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_4.dat
# 19:26 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 19:40 madminer.core        INFO    Run 5
# 19:40 madminer.core        INFO      Sampling from benchmark: sm
# 19:40 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 19:40 madminer.core        INFO      Original Pythia8 card:   None
# 19:40 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_5.dat
# 19:40 madminer.core        INFO      Copied Pythia8 card:     None
# 19:40 madminer.core        INFO      Param card:              /madminer/cards/param_card_5.dat
# 19:40 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_5.dat
# 19:40 madminer.core        INFO      Log file:                run_5.log
# 19:40 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_5.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_5.dat
# 19:40 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 19:58 madminer.core        INFO    Run 6
# 19:58 madminer.core        INFO      Sampling from benchmark: sm
# 19:58 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 19:58 madminer.core        INFO      Original Pythia8 card:   None
# 19:58 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_6.dat
# 19:58 madminer.core        INFO      Copied Pythia8 card:     None
# 19:58 madminer.core        INFO      Param card:              /madminer/cards/param_card_6.dat
# 19:58 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_6.dat
# 19:58 madminer.core        INFO      Log file:                run_6.log
# 19:58 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_6.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_6.dat
# 19:58 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 20:15 madminer.core        INFO    Run 7
# 20:15 madminer.core        INFO      Sampling from benchmark: sm
# 20:15 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 20:15 madminer.core        INFO      Original Pythia8 card:   None
# 20:15 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_7.dat
# 20:15 madminer.core        INFO      Copied Pythia8 card:     None
# 20:15 madminer.core        INFO      Param card:              /madminer/cards/param_card_7.dat
# 20:15 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_7.dat
# 20:15 madminer.core        INFO      Log file:                run_7.log
# 20:15 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_7.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_7.dat
# 20:15 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 20:31 madminer.core        INFO    Run 8
# 20:31 madminer.core        INFO      Sampling from benchmark: sm
# 20:31 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 20:31 madminer.core        INFO      Original Pythia8 card:   None
# 20:31 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_8.dat
# 20:31 madminer.core        INFO      Copied Pythia8 card:     None
# 20:31 madminer.core        INFO      Param card:              /madminer/cards/param_card_8.dat
# 20:31 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_8.dat
# 20:31 madminer.core        INFO      Log file:                run_8.log
# 20:31 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_8.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_8.dat
# 20:31 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 20:46 madminer.core        INFO    Run 9
# 20:46 madminer.core        INFO      Sampling from benchmark: sm
# 20:46 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 20:46 madminer.core        INFO      Original Pythia8 card:   None
# 20:46 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_9.dat
# 20:46 madminer.core        INFO      Copied Pythia8 card:     None
# 20:46 madminer.core        INFO      Param card:              /madminer/cards/param_card_9.dat
# 20:46 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_9.dat
# 20:46 madminer.core        INFO      Log file:                run_9.log
# 20:46 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_9.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_9.dat
# 20:46 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 21:00 madminer.core        INFO    Run 10
# 21:00 madminer.core        INFO      Sampling from benchmark: sm
# 21:00 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 21:00 madminer.core        INFO      Original Pythia8 card:   None
# 21:00 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_10.dat
# 21:00 madminer.core        INFO      Copied Pythia8 card:     None
# 21:00 madminer.core        INFO      Param card:              /madminer/cards/param_card_10.dat
# 21:00 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_10.dat
# 21:00 madminer.core        INFO      Log file:                run_10.log
# 21:00 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_10.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_10.dat
# 21:00 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 21:16 madminer.core        INFO    Run 11
# 21:16 madminer.core        INFO      Sampling from benchmark: sm
# 21:16 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 21:16 madminer.core        INFO      Original Pythia8 card:   None
# 21:16 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_11.dat
# 21:16 madminer.core        INFO      Copied Pythia8 card:     None
# 21:16 madminer.core        INFO      Param card:              /madminer/cards/param_card_11.dat
# 21:16 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_11.dat
# 21:16 madminer.core        INFO      Log file:                run_11.log
# 21:16 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_11.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_11.dat
# 21:16 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 21:30 madminer.core        INFO    Run 12
# 21:30 madminer.core        INFO      Sampling from benchmark: sm
# 21:30 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 21:30 madminer.core        INFO      Original Pythia8 card:   None
# 21:30 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_12.dat
# 21:30 madminer.core        INFO      Copied Pythia8 card:     None
# 21:30 madminer.core        INFO      Param card:              /madminer/cards/param_card_12.dat
# 21:30 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_12.dat
# 21:30 madminer.core        INFO      Log file:                run_12.log
# 21:30 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_12.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_12.dat
# 21:30 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 21:45 madminer.core        INFO    Run 13
# 21:45 madminer.core        INFO      Sampling from benchmark: sm
# 21:45 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 21:45 madminer.core        INFO      Original Pythia8 card:   None
# 21:45 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_13.dat
# 21:45 madminer.core        INFO      Copied Pythia8 card:     None
# 21:45 madminer.core        INFO      Param card:              /madminer/cards/param_card_13.dat
# 21:45 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_13.dat
# 21:45 madminer.core        INFO      Log file:                run_13.log
# 21:45 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_13.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_13.dat
# 21:45 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 22:03 madminer.core        INFO    Run 14
# 22:03 madminer.core        INFO      Sampling from benchmark: sm
# 22:03 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 22:03 madminer.core        INFO      Original Pythia8 card:   None
# 22:03 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_14.dat
# 22:03 madminer.core        INFO      Copied Pythia8 card:     None
# 22:03 madminer.core        INFO      Param card:              /madminer/cards/param_card_14.dat
# 22:03 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_14.dat
# 22:03 madminer.core        INFO      Log file:                run_14.log
# 22:03 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_14.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_14.dat
# 22:03 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 22:17 madminer.core        INFO    Run 15
# 22:17 madminer.core        INFO      Sampling from benchmark: sm
# 22:17 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 22:17 madminer.core        INFO      Original Pythia8 card:   None
# 22:17 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_15.dat
# 22:17 madminer.core        INFO      Copied Pythia8 card:     None
# 22:17 madminer.core        INFO      Param card:              /madminer/cards/param_card_15.dat
# 22:17 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_15.dat
# 22:17 madminer.core        INFO      Log file:                run_15.log
# 22:17 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_15.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_15.dat
# 22:17 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 22:31 madminer.core        INFO    Run 16
# 22:31 madminer.core        INFO      Sampling from benchmark: sm
# 22:31 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 22:31 madminer.core        INFO      Original Pythia8 card:   None
# 22:31 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_16.dat
# 22:31 madminer.core        INFO      Copied Pythia8 card:     None
# 22:31 madminer.core        INFO      Param card:              /madminer/cards/param_card_16.dat
# 22:31 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_16.dat
# 22:31 madminer.core        INFO      Log file:                run_16.log
# 22:31 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_16.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_16.dat
# 22:31 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 22:46 madminer.core        INFO    Run 17
# 22:46 madminer.core        INFO      Sampling from benchmark: sm
# 22:46 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 22:46 madminer.core        INFO      Original Pythia8 card:   None
# 22:46 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_17.dat
# 22:46 madminer.core        INFO      Copied Pythia8 card:     None
# 22:46 madminer.core        INFO      Param card:              /madminer/cards/param_card_17.dat
# 22:46 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_17.dat
# 22:46 madminer.core        INFO      Log file:                run_17.log
# 22:46 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_17.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_17.dat
# 22:46 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 23:01 madminer.core        INFO    Run 18
# 23:01 madminer.core        INFO      Sampling from benchmark: sm
# 23:01 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 23:01 madminer.core        INFO      Original Pythia8 card:   None
# 23:01 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_18.dat
# 23:01 madminer.core        INFO      Copied Pythia8 card:     None
# 23:01 madminer.core        INFO      Param card:              /madminer/cards/param_card_18.dat
# 23:01 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_18.dat
# 23:01 madminer.core        INFO      Log file:                run_18.log
# 23:01 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_18.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_18.dat
# 23:01 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 23:15 madminer.core        INFO    Run 19
# 23:15 madminer.core        INFO      Sampling from benchmark: sm
# 23:15 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 23:15 madminer.core        INFO      Original Pythia8 card:   None
# 23:15 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_19.dat
# 23:15 madminer.core        INFO      Copied Pythia8 card:     None
# 23:15 madminer.core        INFO      Param card:              /madminer/cards/param_card_19.dat
# 23:15 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_19.dat
# 23:15 madminer.core        INFO      Log file:                run_19.log
# 23:15 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_19.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_19.dat
# 23:15 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 23:28 madminer.core        INFO    Run 20
# 23:28 madminer.core        INFO      Sampling from benchmark: sm
# 23:28 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 23:28 madminer.core        INFO      Original Pythia8 card:   None
# 23:28 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_20.dat
# 23:28 madminer.core        INFO      Copied Pythia8 card:     None
# 23:28 madminer.core        INFO      Param card:              /madminer/cards/param_card_20.dat
# 23:28 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_20.dat
# 23:28 madminer.core        INFO      Log file:                run_20.log
# 23:28 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_20.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_20.dat
# 23:28 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 23:45 madminer.core        INFO    Run 21
# 23:45 madminer.core        INFO      Sampling from benchmark: sm
# 23:45 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 23:45 madminer.core        INFO      Original Pythia8 card:   None
# 23:45 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_21.dat
# 23:45 madminer.core        INFO      Copied Pythia8 card:     None
# 23:45 madminer.core        INFO      Param card:              /madminer/cards/param_card_21.dat
# 23:45 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_21.dat
# 23:45 madminer.core        INFO      Log file:                run_21.log
# 23:45 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_21.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_21.dat
# 23:45 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 23:58 madminer.core        INFO    Run 22
# 23:58 madminer.core        INFO      Sampling from benchmark: sm
# 23:58 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 23:58 madminer.core        INFO      Original Pythia8 card:   None
# 23:58 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_22.dat
# 23:58 madminer.core        INFO      Copied Pythia8 card:     None
# 23:58 madminer.core        INFO      Param card:              /madminer/cards/param_card_22.dat
# 23:58 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_22.dat
# 23:58 madminer.core        INFO      Log file:                run_22.log
# 23:58 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_22.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_22.dat
# 23:58 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 00:11 madminer.core        INFO    Run 23
# 00:11 madminer.core        INFO      Sampling from benchmark: sm
# 00:11 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 00:11 madminer.core        INFO      Original Pythia8 card:   None
# 00:11 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_23.dat
# 00:11 madminer.core        INFO      Copied Pythia8 card:     None
# 00:11 madminer.core        INFO      Param card:              /madminer/cards/param_card_23.dat
# 00:11 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_23.dat
# 00:11 madminer.core        INFO      Log file:                run_23.log
# 00:11 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_23.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_23.dat
# 00:11 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 00:24 madminer.core        INFO    Run 24
# 00:24 madminer.core        INFO      Sampling from benchmark: sm
# 00:24 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 00:24 madminer.core        INFO      Original Pythia8 card:   None
# 00:24 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_24.dat
# 00:24 madminer.core        INFO      Copied Pythia8 card:     None
# 00:24 madminer.core        INFO      Param card:              /madminer/cards/param_card_24.dat
# 00:24 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_24.dat
# 00:24 madminer.core        INFO      Log file:                run_24.log
# 00:24 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_24.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_24.dat
# 00:24 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 00:40 madminer.core        INFO    Run 25
# 00:40 madminer.core        INFO      Sampling from benchmark: sm
# 00:40 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 00:40 madminer.core        INFO      Original Pythia8 card:   None
# 00:40 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_25.dat
# 00:40 madminer.core        INFO      Copied Pythia8 card:     None
# 00:40 madminer.core        INFO      Param card:              /madminer/cards/param_card_25.dat
# 00:40 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_25.dat
# 00:40 madminer.core        INFO      Log file:                run_25.log
# 00:40 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_25.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_25.dat
# 00:40 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 00:55 madminer.core        INFO    Run 26
# 00:55 madminer.core        INFO      Sampling from benchmark: sm
# 00:55 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 00:55 madminer.core        INFO      Original Pythia8 card:   None
# 00:55 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_26.dat
# 00:55 madminer.core        INFO      Copied Pythia8 card:     None
# 00:55 madminer.core        INFO      Param card:              /madminer/cards/param_card_26.dat
# 00:55 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_26.dat
# 00:55 madminer.core        INFO      Log file:                run_26.log
# 00:55 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_26.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_26.dat
# 00:55 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 01:08 madminer.core        INFO    Run 27
# 01:08 madminer.core        INFO      Sampling from benchmark: sm
# 01:08 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 01:08 madminer.core        INFO      Original Pythia8 card:   None
# 01:08 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_27.dat
# 01:08 madminer.core        INFO      Copied Pythia8 card:     None
# 01:08 madminer.core        INFO      Param card:              /madminer/cards/param_card_27.dat
# 01:08 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_27.dat
# 01:08 madminer.core        INFO      Log file:                run_27.log
# 01:08 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_27.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_27.dat
# 01:08 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 01:22 madminer.core        INFO    Run 28
# 01:22 madminer.core        INFO      Sampling from benchmark: sm
# 01:22 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 01:22 madminer.core        INFO      Original Pythia8 card:   None
# 01:22 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_28.dat
# 01:22 madminer.core        INFO      Copied Pythia8 card:     None
# 01:22 madminer.core        INFO      Param card:              /madminer/cards/param_card_28.dat
# 01:22 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_28.dat
# 01:22 madminer.core        INFO      Log file:                run_28.log
# 01:22 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_28.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_28.dat
# 01:22 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 01:39 madminer.core        INFO    Run 29
# 01:39 madminer.core        INFO      Sampling from benchmark: sm
# 01:39 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 01:39 madminer.core        INFO      Original Pythia8 card:   None
# 01:39 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_29.dat
# 01:39 madminer.core        INFO      Copied Pythia8 card:     None
# 01:39 madminer.core        INFO      Param card:              /madminer/cards/param_card_29.dat
# 01:39 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_29.dat
# 01:39 madminer.core        INFO      Log file:                run_29.log
# 01:39 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_29.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_29.dat
# 01:39 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 01:54 madminer.core        INFO    Run 30
# 01:54 madminer.core        INFO      Sampling from benchmark: sm
# 01:54 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 01:54 madminer.core        INFO      Original Pythia8 card:   None
# 01:54 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_30.dat
# 01:54 madminer.core        INFO      Copied Pythia8 card:     None
# 01:54 madminer.core        INFO      Param card:              /madminer/cards/param_card_30.dat
# 01:54 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_30.dat
# 01:54 madminer.core        INFO      Log file:                run_30.log
# 01:54 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_30.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_30.dat
# 01:54 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 02:09 madminer.core        INFO    Run 31
# 02:09 madminer.core        INFO      Sampling from benchmark: sm
# 02:09 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 02:09 madminer.core        INFO      Original Pythia8 card:   None
# 02:09 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_31.dat
# 02:09 madminer.core        INFO      Copied Pythia8 card:     None
# 02:09 madminer.core        INFO      Param card:              /madminer/cards/param_card_31.dat
# 02:09 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_31.dat
# 02:09 madminer.core        INFO      Log file:                run_31.log
# 02:09 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_31.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_31.dat
# 02:09 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 02:22 madminer.core        INFO    Run 32
# 02:22 madminer.core        INFO      Sampling from benchmark: sm
# 02:22 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 02:22 madminer.core        INFO      Original Pythia8 card:   None
# 02:22 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_32.dat
# 02:22 madminer.core        INFO      Copied Pythia8 card:     None
# 02:22 madminer.core        INFO      Param card:              /madminer/cards/param_card_32.dat
# 02:22 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_32.dat
# 02:22 madminer.core        INFO      Log file:                run_32.log
# 02:22 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_32.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_32.dat
# 02:22 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 02:34 madminer.core        INFO    Run 33
# 02:34 madminer.core        INFO      Sampling from benchmark: sm
# 02:34 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 02:34 madminer.core        INFO      Original Pythia8 card:   None
# 02:34 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_33.dat
# 02:34 madminer.core        INFO      Copied Pythia8 card:     None
# 02:34 madminer.core        INFO      Param card:              /madminer/cards/param_card_33.dat
# 02:34 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_33.dat
# 02:34 madminer.core        INFO      Log file:                run_33.log
# 02:34 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_33.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_33.dat
# 02:34 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 02:53 madminer.core        INFO    Run 34
# 02:53 madminer.core        INFO      Sampling from benchmark: sm
# 02:53 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 02:53 madminer.core        INFO      Original Pythia8 card:   None
# 02:53 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_34.dat
# 02:53 madminer.core        INFO      Copied Pythia8 card:     None
# 02:53 madminer.core        INFO      Param card:              /madminer/cards/param_card_34.dat
# 02:53 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_34.dat
# 02:53 madminer.core        INFO      Log file:                run_34.log
# 02:53 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_34.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_34.dat
# 02:53 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 03:08 madminer.core        INFO    Run 35
# 03:08 madminer.core        INFO      Sampling from benchmark: sm
# 03:08 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 03:08 madminer.core        INFO      Original Pythia8 card:   None
# 03:08 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_35.dat
# 03:08 madminer.core        INFO      Copied Pythia8 card:     None
# 03:08 madminer.core        INFO      Param card:              /madminer/cards/param_card_35.dat
# 03:08 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_35.dat
# 03:08 madminer.core        INFO      Log file:                run_35.log
# 03:08 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_35.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_35.dat
# 03:08 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 03:23 madminer.core        INFO    Run 36
# 03:23 madminer.core        INFO      Sampling from benchmark: sm
# 03:23 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 03:23 madminer.core        INFO      Original Pythia8 card:   None
# 03:23 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_36.dat
# 03:23 madminer.core        INFO      Copied Pythia8 card:     None
# 03:23 madminer.core        INFO      Param card:              /madminer/cards/param_card_36.dat
# 03:23 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_36.dat
# 03:23 madminer.core        INFO      Log file:                run_36.log
# 03:23 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_36.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_36.dat
# 03:23 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 03:42 madminer.core        INFO    Run 37
# 03:42 madminer.core        INFO      Sampling from benchmark: sm
# 03:42 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 03:42 madminer.core        INFO      Original Pythia8 card:   None
# 03:42 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_37.dat
# 03:42 madminer.core        INFO      Copied Pythia8 card:     None
# 03:42 madminer.core        INFO      Param card:              /madminer/cards/param_card_37.dat
# 03:42 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_37.dat
# 03:42 madminer.core        INFO      Log file:                run_37.log
# 03:42 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_37.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_37.dat
# 03:42 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 03:57 madminer.core        INFO    Run 38
# 03:57 madminer.core        INFO      Sampling from benchmark: sm
# 03:57 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 03:57 madminer.core        INFO      Original Pythia8 card:   None
# 03:57 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_38.dat
# 03:57 madminer.core        INFO      Copied Pythia8 card:     None
# 03:57 madminer.core        INFO      Param card:              /madminer/cards/param_card_38.dat
# 03:57 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_38.dat
# 03:57 madminer.core        INFO      Log file:                run_38.log
# 03:57 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_38.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_38.dat
# 03:57 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 04:14 madminer.core        INFO    Run 39
# 04:14 madminer.core        INFO      Sampling from benchmark: sm
# 04:14 madminer.core        INFO      Original run card:       ../cards/run_card_wh_parton.dat
# 04:14 madminer.core        INFO      Original Pythia8 card:   None
# 04:14 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_39.dat
# 04:14 madminer.core        INFO      Copied Pythia8 card:     None
# 04:14 madminer.core        INFO      Param card:              /madminer/cards/param_card_39.dat
# 04:14 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_39.dat
# 04:14 madminer.core        INFO      Log file:                run_39.log
# 04:14 madminer.core        INFO    Creating param and reweight cards in ./wmh_e_smeftsim//madminer/cards/param_card_39.dat, ./wmh_e_smeftsim//madminer/cards/reweight_card_39.dat
# 04:14 madminer.utils.inter INFO    Starting MadGraph and Pythia in ./wmh_e_smeftsim
# 04:29 madminer.core        INFO    Finished running MadGraph! Please check that events were succesfully generated in the following folders:
#
# ./wmh_e_smeftsim/Events/run_01
# ./wmh_e_smeftsim/Events/run_02
# ./wmh_e_smeftsim/Events/run_03
# ./wmh_e_smeftsim/Events/run_04
# ./wmh_e_smeftsim/Events/run_05
# ./wmh_e_smeftsim/Events/run_06
# ./wmh_e_smeftsim/Events/run_07
# ./wmh_e_smeftsim/Events/run_08
# ./wmh_e_smeftsim/Events/run_09
# ./wmh_e_smeftsim/Events/run_10
# ./wmh_e_smeftsim/Events/run_11
# ./wmh_e_smeftsim/Events/run_12
# ./wmh_e_smeftsim/Events/run_13
# ./wmh_e_smeftsim/Events/run_14
# ./wmh_e_smeftsim/Events/run_15
# ./wmh_e_smeftsim/Events/run_16
# ./wmh_e_smeftsim/Events/run_17
# ./wmh_e_smeftsim/Events/run_18
# ./wmh_e_smeftsim/Events/run_19
# ./wmh_e_smeftsim/Events/run_20
# ./wmh_e_smeftsim/Events/run_21
# ./wmh_e_smeftsim/Events/run_22
# ./wmh_e_smeftsim/Events/run_23
# ./wmh_e_smeftsim/Events/run_24
# ./wmh_e_smeftsim/Events/run_25
# ./wmh_e_smeftsim/Events/run_26
# ./wmh_e_smeftsim/Events/run_27
# ./wmh_e_smeftsim/Events/run_28
# ./wmh_e_smeftsim/Events/run_29
# ./wmh_e_smeftsim/Events/run_30
# ./wmh_e_smeftsim/Events/run_31
# ./wmh_e_smeftsim/Events/run_32
# ./wmh_e_smeftsim/Events/run_33
# ./wmh_e_smeftsim/Events/run_34
# ./wmh_e_smeftsim/Events/run_35
# ./wmh_e_smeftsim/Events/run_36
# ./wmh_e_smeftsim/Events/run_37
# ./wmh_e_smeftsim/Events/run_38
# ./wmh_e_smeftsim/Events/run_39
# ./wmh_e_smeftsim/Events/run_40
